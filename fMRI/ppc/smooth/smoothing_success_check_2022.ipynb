# %%
import os
import glob
import re
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# OK, maybe for each subject and wave we check:
#  - the number of appropriate input files
#  - the number of appropriate output files

# %%
file_dir = '/gpfs/projects/sanlab/shared/DEV/bids_data/derivatives/fmriprep_2022/'

# %%
#iterate through subjects
subj_folder_list = [p.replace(file_dir,"") for p in glob.glob(file_dir + '/sub-DEV*/',recursive=False)]
subj_folder_list.sort()
output_dict_list = []

#count out the number of files for each task in (1) unsmoothed input and (2) smoothed output
task_list = ["ROC","WTP","SST"]
task_correct_acq_set = {
    "ROC":{1,2,3,4},"WTP":{1,2,3,4},"SST":{1}
}

for subj_folder in subj_folder_list:
    #for each subject count the smoothed files by wave and category
    subj_fullpath = file_dir + subj_folder
    wave_list = [p.replace(subj_fullpath,"") for p in glob.glob(subj_fullpath + "ses-wave*")]
    
    #iterate through waves - in most cases, just two
    for wave in wave_list:
        subj_wave_dict = {}
        subj_wave_dict['subj'] = subj_folder
        subj_wave_dict['wave'] = wave
        subj_wave_fullpath = subj_fullpath + wave
        
        #raw_input_list = [p.replace(subj_wave_fullpath,"") for p in glob.glob(subj_wave_fullpath + "/func/sub*bold_space-MNI152NLin2009cAsym_preproc*")]
        #smoothed_output_list = [p.replace(subj_wave_fullpath,"") for p in glob.glob(subj_wave_fullpath + "/func/s6_sub*")]
        

        task_counts_input = {}
        task_counts_smoothed = {}
        task_diff = {}
        
        for task in task_list:
            #check for input matching the canonical number of acqs
            #we should have precisely four, with the values 1, 2, 3, 4 as acquisition groups
            #except for SST which has a smaller dictionary
            
            #match on just the regularly named files
            glob_key = subj_wave_fullpath + "/func/sub*" + task + "*_acq-?_space-MNI152NLin2009cAsym_desc-preproc_bold*"
            task_input_files_regular = [p.replace(subj_wave_fullpath,"") for p in glob.glob(glob_key)]
            acq_groups_input = set([int(re.search("acq-(\d)",fn).group(1)) for fn in task_input_files_regular])
            subj_wave_dict[task + "_missing_input_acq_bool"] = acq_groups_input!=task_correct_acq_set[task]
            subj_wave_dict[task + "_missing_input_acq"] = task_correct_acq_set[task].difference(acq_groups_input)

            #allow matches on irregularly named files
            task_input_files_all = [p.replace(subj_wave_fullpath,"") for p in glob.glob(subj_wave_fullpath + "/func/sub*" + task + "*_acq-*_space-MNI152NLin2009cAsym_desc-preproc_bold*")]
            acq_groups_input_all = set([int(re.search("acq-(\d)",fn).group(1)) for fn in task_input_files_all])
            subj_wave_dict[task + "_missing_entirely_input_acq_bool"] = acq_groups_input_all!=task_correct_acq_set[task]
            subj_wave_dict[task + "_missing_entirely_input_acq"] = task_correct_acq_set[task].difference(acq_groups_input_all)


            #check for output matching the input
            task_output_files = [p.replace(subj_wave_fullpath,"") for p in glob.glob(subj_wave_fullpath + "/func/s6_sub*" + task + "*_acq-?_space-MNI152NLin2009cAsym_desc-preproc_bold*")]
            acq_groups_output = set([int(re.search("acq-(\d)",fn).group(1)) for fn in task_output_files])
            subj_wave_dict[task + "_missing_output_acq_bool"] = acq_groups_output!=task_correct_acq_set[task]
            subj_wave_dict[task + "_missing_output_acq"] = task_correct_acq_set[task].difference(acq_groups_output)
            

        #subj_wave_dict["any_missing_output"] = sum(task_counts_input.values()) - sum(task_counts_smoothed.values())
        subj_wave_dict["any_missing_input_acq_bool"] = any([subj_wave_dict[t + "_missing_input_acq_bool"] for t in task_list])
        subj_wave_dict["any_missing_entirely_input_acq_bool"] = any([subj_wave_dict[t + "_missing_entirely_input_acq_bool"] for t in task_list])
        subj_wave_dict["any_missing_output_acq_bool"] = any([subj_wave_dict[t + "_missing_output_acq_bool"] for t in task_list])
        #print details if not all input files were successfully smoothed
        if sum(task_counts_smoothed.values())<sum(task_counts_input.values()):
            print(subj_folder + ", " + wave)
            print("input:")
            print(task_counts_input)
            print("smoothed:")
            print(task_counts_smoothed)
            print(subj_wave_dict["any_missing_acq_bool"])

        #list specifically which "aacq"
            
        output_dict_list = output_dict_list + [subj_wave_dict]

        
missing_report_df = pd.DataFrame(output_dict_list)

# %%
subj_wave_dict['ROC_missing_input_acq']
# Out:
# set()

# %%
missing_report_df.loc[210,:]
# Out:
# subj                                   sub-DEV116/
# wave                                     ses-wave1
# ROC_missing_input_acq_bool                   False
# ROC_missing_input_acq                           {}
# ROC_missing_entirely_input_acq_bool          False
# ROC_missing_entirely_input_acq                  {}
# ROC_missing_output_acq_bool                  False
# ROC_missing_output_acq                          {}
# WTP_missing_input_acq_bool                   False
# WTP_missing_input_acq                           {}
# WTP_missing_entirely_input_acq_bool          False
# WTP_missing_entirely_input_acq                  {}
# WTP_missing_output_acq_bool                  False
# WTP_missing_output_acq                          {}
# SST_missing_input_acq_bool                   False
# SST_missing_input_acq                           {}
# SST_missing_entirely_input_acq_bool          False
# SST_missing_entirely_input_acq                  {}
# SST_missing_output_acq_bool                  False
# SST_missing_output_acq                          {}
# any_missing_input_acq_bool                   False
# any_missing_entirely_input_acq_bool          False
# any_missing_output_acq_bool                  False
# Name: 210, dtype: object

# %%
missing_report_df.loc[214,:]
# Out:
# subj                                   sub-DEV118/
# wave                                     ses-wave1
# ROC_missing_input_acq_bool                   False
# ROC_missing_input_acq                           {}
# ROC_missing_entirely_input_acq_bool          False
# ROC_missing_entirely_input_acq                  {}
# ROC_missing_output_acq_bool                  False
# ROC_missing_output_acq                          {}
# WTP_missing_input_acq_bool                    True
# WTP_missing_input_acq                          {3}
# WTP_missing_entirely_input_acq_bool           True
# WTP_missing_entirely_input_acq                 {3}
# WTP_missing_output_acq_bool                   True
# WTP_missing_output_acq                      {3, 4}
# SST_missing_input_acq_bool                   False
# SST_missing_input_acq                           {}
# SST_missing_entirely_input_acq_bool          False
# SST_missing_entirely_input_acq                  {}
# SST_missing_output_acq_bool                  False
# SST_missing_output_acq                          {}
# any_missing_input_acq_bool                    True
# any_missing_entirely_input_acq_bool           True
# any_missing_output_acq_bool                   True
# Name: 214, dtype: object

# %%
missing_report_df.any_missing_output_acq_bool.value_counts()
# Out:
# False    517
# True      27
# Name: any_missing_output_acq_bool, dtype: int64

# %%
missing_report_df.loc[missing_report_df.any_missing_output_acq_bool>0,:]
# Out:
#             subj       wave  ROC_missing_input_acq_bool ROC_missing_input_acq  \
# 1    sub-DEV001/  ses-wave2                       False                    {}
# 7    sub-DEV007/  ses-wave1                       False                    {}
# 33   sub-DEV020/  ses-wave2                        True                {3, 4}
# 46   sub-DEV027/  ses-wave2                       False                    {}
# 82   sub-DEV048/  ses-wave1                        True                   {4}
# 108  sub-DEV061/  ses-wave1                       False                    {}
# 109  sub-DEV061/  ses-wave2                       False                    {}
# 149  sub-DEV082/  ses-wave1                       False                    {}
# 170  sub-DEV094/  ses-wave1                        True                   {4}
# 177  sub-DEV098/  ses-wave1                        True                {3, 4}
# 192  sub-DEV106/  ses-wave1                       False                    {}
# 214  sub-DEV118/  ses-wave1                       False                    {}
# 229  sub-DEV126/  ses-wave1                        True          {1, 2, 3, 4}
# 230  sub-DEV126/  ses-wave2                        True          {1, 2, 3, 4}
# 275  sub-DEV154/  ses-wave1                        True                   {4}
# 312  sub-DEV181/  ses-wave1                       False                    {}
# 332  sub-DEV192/  ses-wave1                        True                   {4}
# 345  sub-DEV198/  ses-wave3                        True                   {1}
# 349  sub-DEV200/  ses-wave1                       False                    {}
# 359  sub-DEV205/  ses-wave3                       False                    {}
# 363  sub-DEV207/  ses-wave1                       False                    {}
# 364  sub-DEV207/  ses-wave2                       False                    {}
# 385  sub-DEV221/  ses-wave1                        True                {3, 4}
# 389  sub-DEV223/  ses-wave2                       False                    {}
# 411  sub-DEV237/  ses-wave2                       False                    {}
# 436  sub-DEV253/  ses-wave1                       False                    {}
# 440  sub-DEV255/  ses-wave3                       False                    {}
#
#      ROC_missing_entirely_input_acq_bool ROC_missing_entirely_input_acq  \
# 1                                  False                             {}
# 7                                  False                             {}
# 33                                  True                         {3, 4}
# 46                                 False                             {}
# 82                                  True                            {4}
# 108                                False                             {}
# 109                                False                             {}
# 149                                False                             {}
# 170                                 True                            {4}
# 177                                 True                         {3, 4}
# 192                                False                             {}
# 214                                False                             {}
# 229                                 True                   {1, 2, 3, 4}
# 230                                 True                   {1, 2, 3, 4}
# 275                                 True                            {4}
# 312                                False                             {}
# 332                                 True                            {4}
# 345                                False                             {}
# 349                                False                             {}
# 359                                False                             {}
# 363                                False                             {}
# 364                                False                             {}
# 385                                 True                         {3, 4}
# 389                                False                             {}
# 411                                False                             {}
# 436                                False                             {}
# 440                                False                             {}
#
#      ROC_missing_output_acq_bool ROC_missing_output_acq  \
# 1                          False                     {}
# 7                          False                     {}
# 33                          True                 {3, 4}
# 46                         False                     {}
# 82                          True                    {4}
# 108                        False                     {}
# 109                        False                     {}
# 149                        False                     {}
# 170                         True                    {4}
# 177                         True                 {3, 4}
# 192                        False                     {}
# 214                        False                     {}
# 229                         True           {1, 2, 3, 4}
# 230                         True           {1, 2, 3, 4}
# 275                         True                    {4}
# 312                        False                     {}
# 332                         True                    {4}
# 345                         True           {1, 2, 3, 4}
# 349                        False                     {}
# 359                         True           {1, 2, 3, 4}
# 363                        False                     {}
# 364                        False                     {}
# 385                         True                 {3, 4}
# 389                        False                     {}
# 411                        False                     {}
# 436                        False                     {}
# 440                         True           {1, 2, 3, 4}
#
#      WTP_missing_input_acq_bool WTP_missing_input_acq  ...  \
# 1                         False                    {}  ...
# 7                          True          {1, 2, 3, 4}  ...
# 33                        False                    {}  ...
# 46                        False                    {}  ...
# 82                        False                    {}  ...
# 108                       False                    {}  ...
# 109                       False                    {}  ...
# 149                        True                   {4}  ...
# 170                       False                    {}  ...
# 177                       False                    {}  ...
# 192                        True                   {4}  ...
# 214                        True                   {3}  ...
# 229                        True          {1, 2, 3, 4}  ...
# 230                        True          {1, 2, 3, 4}  ...
# 275                       False                    {}  ...
# 312                       False                    {}  ...
# 332                       False                    {}  ...
# 345                        True                   {1}  ...
# 349                        True                   {3}  ...
# 359                        True                   {1}  ...
# 363                        True                {3, 4}  ...
# 364                       False                    {}  ...
# 385                       False                    {}  ...
# 389                        True                   {4}  ...
# 411                        True                   {3}  ...
# 436                        True                   {4}  ...
# 440                       False                    {}  ...
#
#      WTP_missing_output_acq SST_missing_input_acq_bool  SST_missing_input_acq  \
# 1                        {}                       True                    {1}
# 7              {1, 2, 3, 4}                      False                     {}
# 33                       {}                      False                     {}
# 46                       {}                       True                    {1}
# 82                       {}                      False                     {}
# 108                      {}                       True                    {1}
# 109                      {}                       True                    {1}
# 149                     {4}                      False                     {}
# 170                      {}                      False                     {}
# 177                      {}                      False                     {}
# 192                     {4}                      False                     {}
# 214                  {3, 4}                      False                     {}
# 229            {1, 2, 3, 4}                       True                    {1}
# 230            {1, 2, 3, 4}                       True                    {1}
# 275                      {}                      False                     {}
# 312                      {}                       True                    {1}
# 332                      {}                      False                     {}
# 345            {1, 2, 3, 4}                       True                    {1}
# 349                  {3, 4}                      False                     {}
# 359            {1, 2, 3, 4}                      False                     {}
# 363                  {3, 4}                      False                     {}
# 364                      {}                       True                    {1}
# 385                      {}                       True                    {1}
# 389                     {4}                      False                     {}
# 411                  {3, 4}                      False                     {}
# 436                     {4}                      False                     {}
# 440            {1, 2, 3, 4}                      False                     {}
#
#     SST_missing_entirely_input_acq_bool  SST_missing_entirely_input_acq  \
# 1                                  True                             {1}
# 7                                 False                              {}
# 33                                False                              {}
# 46                                 True                             {1}
# 82                                False                              {}
# 108                                True                             {1}
# 109                                True                             {1}
# 149                               False                              {}
# 170                               False                              {}
# 177                               False                              {}
# 192                               False                              {}
# 214                               False                              {}
# 229                                True                             {1}
# 230                                True                             {1}
# 275                               False                              {}
# 312                                True                             {1}
# 332                               False                              {}
# 345                               False                              {}
# 349                               False                              {}
# 359                               False                              {}
# 363                               False                              {}
# 364                                True                             {1}
# 385                                True                             {1}
# 389                               False                              {}
# 411                               False                              {}
# 436                               False                              {}
# 440                               False                              {}
#
#     SST_missing_output_acq_bool  SST_missing_output_acq  \
# 1                          True                     {1}
# 7                         False                      {}
# 33                        False                      {}
# 46                         True                     {1}
# 82                        False                      {}
# 108                        True                     {1}
# 109                        True                     {1}
# 149                       False                      {}
# 170                       False                      {}
# 177                       False                      {}
# 192                       False                      {}
# 214                       False                      {}
# 229                        True                     {1}
# 230                        True                     {1}
# 275                       False                      {}
# 312                        True                     {1}
# 332                       False                      {}
# 345                        True                     {1}
# 349                       False                      {}
# 359                        True                     {1}
# 363                       False                      {}
# 364                        True                     {1}
# 385                        True                     {1}
# 389                       False                      {}
# 411                       False                      {}
# 436                       False                      {}
# 440                        True                     {1}
#
#     any_missing_input_acq_bool  any_missing_entirely_input_acq_bool  \
# 1                         True                                 True
# 7                         True                                 True
# 33                        True                                 True
# 46                        True                                 True
# 82                        True                                 True
# 108                       True                                 True
# 109                       True                                 True
# 149                       True                                 True
# 170                       True                                 True
# 177                       True                                 True
# 192                       True                                 True
# 214                       True                                 True
# 229                       True                                 True
# 230                       True                                 True
# 275                       True                                 True
# 312                       True                                 True
# 332                       True                                 True
# 345                       True                                False
# 349                       True                                 True
# 359                       True                                False
# 363                       True                                 True
# 364                       True                                 True
# 385                       True                                 True
# 389                       True                                 True
# 411                       True                                 True
# 436                       True                                 True
# 440                      False                                False
#
#     any_missing_output_acq_bool
# 1                          True
# 7                          True
# 33                         True
# 46                         True
# 82                         True
# 108                        True
# 109                        True
# 149                        True
# 170                        True
# 177                        True
# 192                        True
# 214                        True
# 229                        True
# 230                        True
# 275                        True
# 312                        True
# 332                        True
# 345                        True
# 349                        True
# 359                        True
# 363                        True
# 364                        True
# 385                        True
# 389                        True
# 411                        True
# 436                        True
# 440                        True
#
# [27 rows x 23 columns]

# %%
missing_report_df
# Out:
#             subj       wave  ROC_missing_input_acq_bool ROC_missing_input_acq  \
# 0    sub-DEV001/  ses-wave1                       False                    {}
# 1    sub-DEV001/  ses-wave2                       False                    {}
# 2    sub-DEV004/  ses-wave1                       False                    {}
# 3    sub-DEV004/  ses-wave2                       False                    {}
# 4    sub-DEV005/  ses-wave1                       False                    {}
# ..           ...        ...                         ...                   ...
# 539  sub-DEV310/  ses-wave2                       False                    {}
# 540  sub-DEV311/  ses-wave1                       False                    {}
# 541  sub-DEV311/  ses-wave2                       False                    {}
# 542  sub-DEV312/  ses-wave1                       False                    {}
# 543  sub-DEV312/  ses-wave2                       False                    {}
#
#      ROC_missing_entirely_input_acq_bool ROC_missing_entirely_input_acq  \
# 0                                  False                             {}
# 1                                  False                             {}
# 2                                  False                             {}
# 3                                  False                             {}
# 4                                  False                             {}
# ..                                   ...                            ...
# 539                                False                             {}
# 540                                False                             {}
# 541                                False                             {}
# 542                                False                             {}
# 543                                False                             {}
#
#      ROC_missing_output_acq_bool ROC_missing_output_acq  \
# 0                          False                     {}
# 1                          False                     {}
# 2                          False                     {}
# 3                          False                     {}
# 4                          False                     {}
# ..                           ...                    ...
# 539                        False                     {}
# 540                        False                     {}
# 541                        False                     {}
# 542                        False                     {}
# 543                        False                     {}
#
#      WTP_missing_input_acq_bool WTP_missing_input_acq  ...  \
# 0                         False                    {}  ...
# 1                         False                    {}  ...
# 2                         False                    {}  ...
# 3                         False                    {}  ...
# 4                         False                    {}  ...
# ..                          ...                   ...  ...
# 539                       False                    {}  ...
# 540                       False                    {}  ...
# 541                       False                    {}  ...
# 542                       False                    {}  ...
# 543                       False                    {}  ...
#
#      WTP_missing_output_acq SST_missing_input_acq_bool  SST_missing_input_acq  \
# 0                        {}                      False                     {}
# 1                        {}                       True                    {1}
# 2                        {}                      False                     {}
# 3                        {}                      False                     {}
# 4                        {}                      False                     {}
# ..                      ...                        ...                    ...
# 539                      {}                      False                     {}
# 540                      {}                      False                     {}
# 541                      {}                      False                     {}
# 542                      {}                      False                     {}
# 543                      {}                      False                     {}
#
#     SST_missing_entirely_input_acq_bool  SST_missing_entirely_input_acq  \
# 0                                 False                              {}
# 1                                  True                             {1}
# 2                                 False                              {}
# 3                                 False                              {}
# 4                                 False                              {}
# ..                                  ...                             ...
# 539                               False                              {}
# 540                               False                              {}
# 541                               False                              {}
# 542                               False                              {}
# 543                               False                              {}
#
#     SST_missing_output_acq_bool  SST_missing_output_acq  \
# 0                         False                      {}
# 1                          True                     {1}
# 2                         False                      {}
# 3                         False                      {}
# 4                         False                      {}
# ..                          ...                     ...
# 539                       False                      {}
# 540                       False                      {}
# 541                       False                      {}
# 542                       False                      {}
# 543                       False                      {}
#
#     any_missing_input_acq_bool  any_missing_entirely_input_acq_bool  \
# 0                        False                                False
# 1                         True                                 True
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 539                      False                                False
# 540                      False                                False
# 541                      False                                False
# 542                      False                                False
# 543                      False                                False
#
#     any_missing_output_acq_bool
# 0                         False
# 1                          True
# 2                         False
# 3                         False
# 4                         False
# ..                          ...
# 539                       False
# 540                       False
# 541                       False
# 542                       False
# 543                       False
#
# [544 rows x 23 columns]

# %%
missing_report_df.groupby(['wave','SST_missing_input_acq_bool','SST_missing_output_acq_bool']).subj.count().sort_index()
# Out:
# wave       SST_missing_input_acq_bool  SST_missing_output_acq_bool
# ses-wave1  False                       False                          281
#            True                        True                             4
# ses-wave2  False                       False                          251
#            True                        True                             5
# ses-wave3  False                       True                             2
#            True                        True                             1
# Name: subj, dtype: int64

# %%
missing_report_df.groupby(['wave','ROC_missing_input_acq_bool','ROC_missing_output_acq_bool']).subj.count().sort_index()
# Out:
# wave       ROC_missing_input_acq_bool  ROC_missing_output_acq_bool
# ses-wave1  False                       False                          278
#            True                        True                             7
# ses-wave2  False                       False                          254
#            True                        True                             2
# ses-wave3  False                       True                             2
#            True                        True                             1
# Name: subj, dtype: int64

# %%
missing_report_df.groupby(['wave','WTP_missing_input_acq_bool','WTP_missing_output_acq_bool']).subj.count().sort_index()
# Out:
# wave       WTP_missing_input_acq_bool  WTP_missing_output_acq_bool
# ses-wave1  False                       False                          277
#            True                        True                             8
# ses-wave2  False                       False                          253
#            True                        True                             3
# ses-wave3  False                       True                             1
#            True                        True                             2
# Name: subj, dtype: int64

# %%
missing_report_df.loc[(missing_report_df.ROC_missing_output_acq_bool) | (missing_report_df.WTP_missing_input_acq_bool),:]
# Out:
#             subj       wave  ROC_missing_input_acq_bool ROC_missing_input_acq  \
# 7    sub-DEV007/  ses-wave1                       False                    {}
# 33   sub-DEV020/  ses-wave2                        True                {3, 4}
# 82   sub-DEV048/  ses-wave1                        True                   {4}
# 149  sub-DEV082/  ses-wave1                       False                    {}
# 170  sub-DEV094/  ses-wave1                        True                   {4}
# 177  sub-DEV098/  ses-wave1                        True                {3, 4}
# 192  sub-DEV106/  ses-wave1                       False                    {}
# 214  sub-DEV118/  ses-wave1                       False                    {}
# 229  sub-DEV126/  ses-wave1                        True          {1, 2, 3, 4}
# 230  sub-DEV126/  ses-wave2                        True          {1, 2, 3, 4}
# 275  sub-DEV154/  ses-wave1                        True                   {4}
# 332  sub-DEV192/  ses-wave1                        True                   {4}
# 345  sub-DEV198/  ses-wave3                        True                   {1}
# 349  sub-DEV200/  ses-wave1                       False                    {}
# 359  sub-DEV205/  ses-wave3                       False                    {}
# 363  sub-DEV207/  ses-wave1                       False                    {}
# 385  sub-DEV221/  ses-wave1                        True                {3, 4}
# 389  sub-DEV223/  ses-wave2                       False                    {}
# 411  sub-DEV237/  ses-wave2                       False                    {}
# 436  sub-DEV253/  ses-wave1                       False                    {}
# 440  sub-DEV255/  ses-wave3                       False                    {}
#
#      ROC_missing_entirely_input_acq_bool ROC_missing_entirely_input_acq  \
# 7                                  False                             {}
# 33                                  True                         {3, 4}
# 82                                  True                            {4}
# 149                                False                             {}
# 170                                 True                            {4}
# 177                                 True                         {3, 4}
# 192                                False                             {}
# 214                                False                             {}
# 229                                 True                   {1, 2, 3, 4}
# 230                                 True                   {1, 2, 3, 4}
# 275                                 True                            {4}
# 332                                 True                            {4}
# 345                                False                             {}
# 349                                False                             {}
# 359                                False                             {}
# 363                                False                             {}
# 385                                 True                         {3, 4}
# 389                                False                             {}
# 411                                False                             {}
# 436                                False                             {}
# 440                                False                             {}
#
#      ROC_missing_output_acq_bool ROC_missing_output_acq  \
# 7                          False                     {}
# 33                          True                 {3, 4}
# 82                          True                    {4}
# 149                        False                     {}
# 170                         True                    {4}
# 177                         True                 {3, 4}
# 192                        False                     {}
# 214                        False                     {}
# 229                         True           {1, 2, 3, 4}
# 230                         True           {1, 2, 3, 4}
# 275                         True                    {4}
# 332                         True                    {4}
# 345                         True           {1, 2, 3, 4}
# 349                        False                     {}
# 359                         True           {1, 2, 3, 4}
# 363                        False                     {}
# 385                         True                 {3, 4}
# 389                        False                     {}
# 411                        False                     {}
# 436                        False                     {}
# 440                         True           {1, 2, 3, 4}
#
#      WTP_missing_input_acq_bool WTP_missing_input_acq  ...  \
# 7                          True          {1, 2, 3, 4}  ...
# 33                        False                    {}  ...
# 82                        False                    {}  ...
# 149                        True                   {4}  ...
# 170                       False                    {}  ...
# 177                       False                    {}  ...
# 192                        True                   {4}  ...
# 214                        True                   {3}  ...
# 229                        True          {1, 2, 3, 4}  ...
# 230                        True          {1, 2, 3, 4}  ...
# 275                       False                    {}  ...
# 332                       False                    {}  ...
# 345                        True                   {1}  ...
# 349                        True                   {3}  ...
# 359                        True                   {1}  ...
# 363                        True                {3, 4}  ...
# 385                       False                    {}  ...
# 389                        True                   {4}  ...
# 411                        True                   {3}  ...
# 436                        True                   {4}  ...
# 440                       False                    {}  ...
#
#      WTP_missing_output_acq SST_missing_input_acq_bool  SST_missing_input_acq  \
# 7              {1, 2, 3, 4}                      False                     {}
# 33                       {}                      False                     {}
# 82                       {}                      False                     {}
# 149                     {4}                      False                     {}
# 170                      {}                      False                     {}
# 177                      {}                      False                     {}
# 192                     {4}                      False                     {}
# 214                  {3, 4}                      False                     {}
# 229            {1, 2, 3, 4}                       True                    {1}
# 230            {1, 2, 3, 4}                       True                    {1}
# 275                      {}                      False                     {}
# 332                      {}                      False                     {}
# 345            {1, 2, 3, 4}                       True                    {1}
# 349                  {3, 4}                      False                     {}
# 359            {1, 2, 3, 4}                      False                     {}
# 363                  {3, 4}                      False                     {}
# 385                      {}                       True                    {1}
# 389                     {4}                      False                     {}
# 411                  {3, 4}                      False                     {}
# 436                     {4}                      False                     {}
# 440            {1, 2, 3, 4}                      False                     {}
#
#     SST_missing_entirely_input_acq_bool  SST_missing_entirely_input_acq  \
# 7                                 False                              {}
# 33                                False                              {}
# 82                                False                              {}
# 149                               False                              {}
# 170                               False                              {}
# 177                               False                              {}
# 192                               False                              {}
# 214                               False                              {}
# 229                                True                             {1}
# 230                                True                             {1}
# 275                               False                              {}
# 332                               False                              {}
# 345                               False                              {}
# 349                               False                              {}
# 359                               False                              {}
# 363                               False                              {}
# 385                                True                             {1}
# 389                               False                              {}
# 411                               False                              {}
# 436                               False                              {}
# 440                               False                              {}
#
#     SST_missing_output_acq_bool  SST_missing_output_acq  \
# 7                         False                      {}
# 33                        False                      {}
# 82                        False                      {}
# 149                       False                      {}
# 170                       False                      {}
# 177                       False                      {}
# 192                       False                      {}
# 214                       False                      {}
# 229                        True                     {1}
# 230                        True                     {1}
# 275                       False                      {}
# 332                       False                      {}
# 345                        True                     {1}
# 349                       False                      {}
# 359                        True                     {1}
# 363                       False                      {}
# 385                        True                     {1}
# 389                       False                      {}
# 411                       False                      {}
# 436                       False                      {}
# 440                        True                     {1}
#
#     any_missing_input_acq_bool  any_missing_entirely_input_acq_bool  \
# 7                         True                                 True
# 33                        True                                 True
# 82                        True                                 True
# 149                       True                                 True
# 170                       True                                 True
# 177                       True                                 True
# 192                       True                                 True
# 214                       True                                 True
# 229                       True                                 True
# 230                       True                                 True
# 275                       True                                 True
# 332                       True                                 True
# 345                       True                                False
# 349                       True                                 True
# 359                       True                                False
# 363                       True                                 True
# 385                       True                                 True
# 389                       True                                 True
# 411                       True                                 True
# 436                       True                                 True
# 440                      False                                False
#
#     any_missing_output_acq_bool
# 7                          True
# 33                         True
# 82                         True
# 149                        True
# 170                        True
# 177                        True
# 192                        True
# 214                        True
# 229                        True
# 230                        True
# 275                        True
# 332                        True
# 345                        True
# 349                        True
# 359                        True
# 363                        True
# 385                        True
# 389                        True
# 411                        True
# 436                        True
# 440                        True
#
# [21 rows x 23 columns]

# %%
subj_wave_fullpath = file_dir + "sub-DEV118/ses-wave1/"
print(subj_wave_fullpath)
[p.replace(subj_wave_fullpath,"") for p in glob.glob(subj_wave_fullpath + "/func/sub*WTP*bold_space-MNI152NLin2009cAsym_preproc*")]
# Out:
# /gpfs/projects/sanlab/shared/DEV/bids_data/derivatives/fmriprep_2022/sub-DEV118/ses-wave1/
# []

# %%
subj_wave_fullpath = file_dir + "sub-DEV116/ses-wave1/"
print(subj_wave_fullpath)
[p.replace(subj_wave_fullpath,"") for p in glob.glob(subj_wave_fullpath + "/func/sub*WTP*bold_space-MNI152NLin2009cAsym_preproc*")]
# Out:
# /gpfs/projects/sanlab/shared/DEV/bids_data/derivatives/fmriprep_2022/sub-DEV116/ses-wave1/
# []

# %%
#specifically which "acq" exist for this subject?

# %% [markdown]
# ## Get a list of all the missing acq runs

# %%
missing_report_df.columns
# Out:
# Index(['subj', 'wave', 'ROC_missing_input_acq_bool', 'ROC_missing_input_acq',
#        'ROC_missing_entirely_input_acq_bool', 'ROC_missing_entirely_input_acq',
#        'ROC_missing_output_acq_bool', 'ROC_missing_output_acq',
#        'WTP_missing_input_acq_bool', 'WTP_missing_input_acq',
#        'WTP_missing_entirely_input_acq_bool', 'WTP_missing_entirely_input_acq',
#        'WTP_missing_output_acq_bool', 'WTP_missing_output_acq',
#        'SST_missing_input_acq_bool', 'SST_missing_input_acq',
#        'SST_missing_entirely_input_acq_bool', 'SST_missing_entirely_input_acq',
#        'SST_missing_output_acq_bool', 'SST_missing_output_acq',
#        'any_missing_input_acq_bool', 'any_missing_entirely_input_acq_bool',
#        'any_missing_output_acq_bool'],
#       dtype='object')

# %%
waves_with_missing_input = missing_report_df.loc[:,[
    'ROC_missing_input_acq',
    'WTP_missing_input_acq','SST_missing_input_acq'
                       ]].any(1)
waves_with_missing_data = waves_with_missing_input |  (missing_report_df.any_missing_output_acq_bool>0)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Just the items with missing input data

# %%
missing_report_df.columns
# Out:
# Index(['subj', 'wave', 'ROC_missing_input_acq_bool', 'ROC_missing_input_acq',
#        'ROC_missing_entirely_input_acq_bool', 'ROC_missing_entirely_input_acq',
#        'ROC_missing_output_acq_bool', 'ROC_missing_output_acq',
#        'WTP_missing_input_acq_bool', 'WTP_missing_input_acq',
#        'WTP_missing_entirely_input_acq_bool', 'WTP_missing_entirely_input_acq',
#        'WTP_missing_output_acq_bool', 'WTP_missing_output_acq',
#        'SST_missing_input_acq_bool', 'SST_missing_input_acq',
#        'SST_missing_entirely_input_acq_bool', 'SST_missing_entirely_input_acq',
#        'SST_missing_output_acq_bool', 'SST_missing_output_acq',
#        'any_missing_input_acq_bool', 'any_missing_entirely_input_acq_bool',
#        'any_missing_output_acq_bool'],
#       dtype='object')

# %%
waves_with_missing_data_info = (missing_report_df.
    loc[waves_with_missing_input]
    .loc[:,['subj','wave','ROC_missing_input_acq',
            'WTP_missing_input_acq','SST_missing_input_acq',
            'ROC_missing_entirely_input_acq',
            'WTP_missing_entirely_input_acq','SST_missing_entirely_input_acq',
            'any_missing_output_acq_bool'
           ]]
                          )

display(waves_with_missing_data_info)

waves_with_missing_data_info.to_csv("waves_with_missing_input_data.csv")
# Out:
#             subj       wave ROC_missing_input_acq WTP_missing_input_acq  \
# 1    sub-DEV001/  ses-wave2                    {}                    {}
# 7    sub-DEV007/  ses-wave1                    {}          {1, 2, 3, 4}
# 33   sub-DEV020/  ses-wave2                {3, 4}                    {}
# 46   sub-DEV027/  ses-wave2                    {}                    {}
# 82   sub-DEV048/  ses-wave1                   {4}                    {}
# 108  sub-DEV061/  ses-wave1                    {}                    {}
# 109  sub-DEV061/  ses-wave2                    {}                    {}
# 149  sub-DEV082/  ses-wave1                    {}                   {4}
# 170  sub-DEV094/  ses-wave1                   {4}                    {}
# 177  sub-DEV098/  ses-wave1                {3, 4}                    {}
# 192  sub-DEV106/  ses-wave1                    {}                   {4}
# 214  sub-DEV118/  ses-wave1                    {}                   {3}
# 229  sub-DEV126/  ses-wave1          {1, 2, 3, 4}          {1, 2, 3, 4}
# 230  sub-DEV126/  ses-wave2          {1, 2, 3, 4}          {1, 2, 3, 4}
# 275  sub-DEV154/  ses-wave1                   {4}                    {}
# 312  sub-DEV181/  ses-wave1                    {}                    {}
# 332  sub-DEV192/  ses-wave1                   {4}                    {}
# 345  sub-DEV198/  ses-wave3                   {1}                   {1}
# 349  sub-DEV200/  ses-wave1                    {}                   {3}
# 359  sub-DEV205/  ses-wave3                    {}                   {1}
# 363  sub-DEV207/  ses-wave1                    {}                {3, 4}
# 364  sub-DEV207/  ses-wave2                    {}                    {}
# 385  sub-DEV221/  ses-wave1                {3, 4}                    {}
# 389  sub-DEV223/  ses-wave2                    {}                   {4}
# 411  sub-DEV237/  ses-wave2                    {}                   {3}
# 436  sub-DEV253/  ses-wave1                    {}                   {4}
#
#     SST_missing_input_acq ROC_missing_entirely_input_acq  \
# 1                     {1}                             {}
# 7                      {}                             {}
# 33                     {}                         {3, 4}
# 46                    {1}                             {}
# 82                     {}                            {4}
# 108                   {1}                             {}
# 109                   {1}                             {}
# 149                    {}                             {}
# 170                    {}                            {4}
# 177                    {}                         {3, 4}
# 192                    {}                             {}
# 214                    {}                             {}
# 229                   {1}                   {1, 2, 3, 4}
# 230                   {1}                   {1, 2, 3, 4}
# 275                    {}                            {4}
# 312                   {1}                             {}
# 332                    {}                            {4}
# 345                   {1}                             {}
# 349                    {}                             {}
# 359                    {}                             {}
# 363                    {}                             {}
# 364                   {1}                             {}
# 385                   {1}                         {3, 4}
# 389                    {}                             {}
# 411                    {}                             {}
# 436                    {}                             {}
#
#     WTP_missing_entirely_input_acq SST_missing_entirely_input_acq  \
# 1                               {}                            {1}
# 7                     {1, 2, 3, 4}                             {}
# 33                              {}                             {}
# 46                              {}                            {1}
# 82                              {}                             {}
# 108                             {}                            {1}
# 109                             {}                            {1}
# 149                            {4}                             {}
# 170                             {}                             {}
# 177                             {}                             {}
# 192                            {4}                             {}
# 214                            {3}                             {}
# 229                   {1, 2, 3, 4}                            {1}
# 230                   {1, 2, 3, 4}                            {1}
# 275                             {}                             {}
# 312                             {}                            {1}
# 332                             {}                             {}
# 345                             {}                             {}
# 349                            {3}                             {}
# 359                             {}                             {}
# 363                         {3, 4}                             {}
# 364                             {}                            {1}
# 385                             {}                            {1}
# 389                            {4}                             {}
# 411                            {3}                             {}
# 436                            {4}                             {}
#
#      any_missing_output_acq_bool
# 1                           True
# 7                           True
# 33                          True
# 46                          True
# 82                          True
# 108                         True
# 109                         True
# 149                         True
# 170                         True
# 177                         True
# 192                         True
# 214                         True
# 229                         True
# 230                         True
# 275                         True
# 312                         True
# 332                         True
# 345                         True
# 349                         True
# 359                         True
# 363                         True
# 364                         True
# 385                         True
# 389                         True
# 411                         True
# 436                         True

# %% [markdown]
# and what about...can we get a list of the waves that have no missing input data but seem to have missing out put data for some reason?
#
# A lto of the wave2 will be based on problems in the prior category in wave1 that caused wave 2 to be aborted too.
#
# So we'll ignore wave 1 and just focus on wave 1 for now...

# %%
waves_with_good_input_but_missing_output = missing_report_df.loc[(
    (missing_report_df.any_missing_input_acq_bool==False) & 
    (missing_report_df.any_missing_output_acq_bool==True) &
    (missing_report_df.wave=='ses-wave1')
),:]

waves_with_good_input_but_missing_output
# Out:
# Empty DataFrame
# Columns: [subj, wave, ROC_missing_input_acq_bool, ROC_missing_input_acq, ROC_missing_entirely_input_acq_bool, ROC_missing_entirely_input_acq, ROC_missing_output_acq_bool, ROC_missing_output_acq, WTP_missing_input_acq_bool, WTP_missing_input_acq, WTP_missing_entirely_input_acq_bool, WTP_missing_entirely_input_acq, WTP_missing_output_acq_bool, WTP_missing_output_acq, SST_missing_input_acq_bool, SST_missing_input_acq, SST_missing_entirely_input_acq_bool, SST_missing_entirely_input_acq, SST_missing_output_acq_bool, SST_missing_output_acq, any_missing_input_acq_bool, any_missing_entirely_input_acq_bool, any_missing_output_acq_bool]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# Finally we should have a look at the wave2's as well.

# %%
waves_with_good_input_but_missing_output = missing_report_df.loc[(
    (missing_report_df.any_missing_input_acq_bool==False) & 
    (missing_report_df.any_missing_output_acq_bool==True) &
    (missing_report_df.wave=='ses-wave2')
),:]

waves_with_good_input_but_missing_output
# Out:
# Empty DataFrame
# Columns: [subj, wave, ROC_missing_input_acq_bool, ROC_missing_input_acq, ROC_missing_entirely_input_acq_bool, ROC_missing_entirely_input_acq, ROC_missing_output_acq_bool, ROC_missing_output_acq, WTP_missing_input_acq_bool, WTP_missing_input_acq, WTP_missing_entirely_input_acq_bool, WTP_missing_entirely_input_acq, WTP_missing_output_acq_bool, WTP_missing_output_acq, SST_missing_input_acq_bool, SST_missing_input_acq, SST_missing_entirely_input_acq_bool, SST_missing_entirely_input_acq, SST_missing_output_acq_bool, SST_missing_output_acq, any_missing_input_acq_bool, any_missing_entirely_input_acq_bool, any_missing_output_acq_bool]
# Index: []
#
# [0 rows x 23 columns]
