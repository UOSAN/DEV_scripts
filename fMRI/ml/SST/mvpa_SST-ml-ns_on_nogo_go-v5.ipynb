# %%
import pandas as pd
import numpy as np
import scipy.io
import re
import sys
import warnings
import pickle

# %%
import pickle
from IPython.core.display import display, HTML, Markdown
# Out:
# /tmp/ipykernel_17144/659417397.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, Markdown

# %%
from sklearn.svm import SVC
from mvpa2.measures.base import CrossValidation
from mvpa2.clfs.meta import NFoldPartitioner
from mvpa2.clfs.svm import LinearCSVMC
from sklearn.calibration import CalibratedClassifierCV
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/mvpa2/datasets/base.py:465: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def __init__(self, shape=None, sid=None, fid=None, dtype=np.float):

# %%
from mvpa2.datasets.mri import fmri_dataset

# %%
class BehavioralDataNotFoundForBrainDataException(Exception):
    """Behavioral data could not be matched to a subject."""
    pass

# %%
from nilearn.masking import unmask

# %% [markdown]
# Replicating earlier work on mvpa. Try not to overly complicate it--the main point is just to verify we get similar results on a different package to validate prior work. ANd we are primarily interested in validating the very high cross-validation results I got with nltools. Should aim for readable code.
#
#
# Version 5 uses scikit-learn directly, bypassing mvpa2's framework altogether. We also implement a 'forced choice' scorer.

# %%
from visualization import visualize_corr
import mvpa2
# Out:
# /gpfs/projects/sanlab/shared/DEV/DEV_scripts/fMRI/ml/SST/visualization.py:7: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, Markdown

# %%
from mvpa_sst_utils import *
# Out:
# /gpfs/projects/sanlab/shared/DEV/DEV_scripts/fMRI/ml/SST/mvpa_sst_utils.py:10: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, Markdown
# /gpfs/projects/sanlab/shared/DEV/DEV_scripts/fMRI/ml/SST/outlier_detection.py:7: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, Markdown

# %%
import sys
import os

sys.path.append(os.path.abspath("../../ml/"))

# %% [markdown]
# ## Load

# %%
nonbids_data_path = "/gpfs/projects/sanlab/shared/DEV/nonbids_data/"
ml_data_folderpath = "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml"

# %%
include_exclude_list = pd.read_csv("../nsc_subject_exclusions.csv")

# %%
test_train_df_raw = pd.read_csv(nonbids_data_path + "fMRI/ml/train_test_markers_20211027T173724.csv")
test_train_df_raw = test_train_df_raw.merge(include_exclude_list[include_exclude_list.Task=='SST'],left_on='sub_label',right_on='SubjectId',how='left')
test_train_df_raw.loc[test_train_df_raw.Include.isna(),'Include'] = True
test_train_df = test_train_df_raw[test_train_df_raw.Include==True]
exclude_subjects = ['DEV061','DEV185','DEV187','DEV189','DEV190','DEV192','DEV198','DEV203','DEV220','DEV221']
train_subjs = test_train_df.loc[test_train_df.SplitGroup=='Train','sub_label'].tolist()#only get the train subjects; ignore those previously marked hold-out

# %%
train_subjs_selected = [ts for ts in train_subjs if (ts not in exclude_subjects)]

# %%
individual_differences = pd.read_csv(ml_data_folderpath + "/data_by_ppt_2022_02_26.csv")
individual_differences = individual_differences.rename(columns={'SID':'subject'})
individual_differences['wave']=1

# %% [markdown]
# We probably actually want to start the pipeline from the betas rather than loading from pickle. to be continued...

# %%
from mvpa_pipeline_utils import get_Brain_Data_betas_as_mvpa_for_sub, import_beta_series_pymvpa2, sa_to_df

# %% [markdown]
# ## new code

# %%
from sklearn.model_selection import LeaveOneGroupOut

# %%
def remove_selected_outliers_mvpa_tesq_study(
    ind_div_combined,
    show_plot=False,
    neural_measures = ['CorGo_ln_inv_pred_prob_CorrectGo','CorStop_ln_inv_pred_prob_CorrectStop']):
    idc_outliers_removed = remove_selected_outliers(ind_div_combined,
    ['BFI_extraversion','RMQ_locomotion','ses_aggregate','PLAN_cognitive_strategies',
     'SST_SSRT','BIS_11','BSCS','TESQ_E_suppression', 'TESQ_E_avoidance_of_temptations', 
     'TESQ_E_goal_deliberation', 'TESQ_E_controlling_temptations', 'TESQ_E_distraction',
     'TESQ_E_goal_and_rule_setting','TESQ_E_sum','EDM','RS','TRSQ','ROC_Crave_Regulate_Minus_Look',
     'SRHI_unhealthy','cancer_promoting_minus_preventing_FFQ','bf_1'] + neural_measures,
    show_plot=show_plot)
    return(idc_outliers_removed)

# %%
import math

# %% [markdown]
# ## whole brain

# %% [raw]
# from sklearn.svm import SVC
# from mvpa2.measures.base import CrossValidation
# from mvpa2.clfs.meta import NFoldPartitioner
# from mvpa2.clfs.svm import LinearCSVMC
# from sklearn.calibration import CalibratedClassifierCV

# %%
from sklearn.model_selection import LeaveOneGroupOut

# %%
from sklearn.svm import SVC
#from mvpa2.measures.base import CrossValidation
#from mvpa2.clfs.meta import NFoldPartitioner
#from mvpa2.clfs.svm import LinearCSVMC
from sklearn.calibration import CalibratedClassifierCV

# %% [markdown]
# Now let's scale that up to the full dataset.

# %%
brain_data_filepath = ml_data_folderpath + '/SST/mvpa_Dataset_conditions_84subs_correct_cond.pkl'

# %%
results_filepath=ml_data_folderpath + "/SST/ttr_mvpa2_res_v5_conditions_84subs_twoclasses_wholebrain.pkl"
#results_filepath=ml_data_folderpath + "/SST/train_test_results_" + dataset_name + "_58subs_twoclasses_pfcmask_repeat1.pkl"

relevant_mask = None

# %%
with open(brain_data_filepath, 'rb') as pkl_file:
    Brain_Data_allsubs = pickle.load(pkl_file)

# %%
Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)

# %%
print(os.path.exists(results_filepath))
# Out:
# False

# %%
if os.path.exists(results_filepath):
    with open(results_filepath, 'rb') as pkl_file:
        forced_choice_results = pickle.load(pkl_file)
else:
    forced_choice_results = do_forced_choice(Brain_Data_allsubs)
    with open(results_filepath, 'wb') as pkl_file:
        pickle.dump(forced_choice_results,file=pkl_file)
# Out:
# ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <module>
#       3         forced_choice_results = pickle.load(pkl_file)
#       4 else:
# ----> 5     forced_choice_results = do_forced_choice(Brain_Data_allsubs)
#       6     with open(results_filepath, 'wb') as pkl_file:
#       7         pickle.dump(forced_choice_results,file=pkl_file)
#
# File /gpfs/projects/sanlab/shared/DEV/DEV_scripts/fMRI/ml/SST/mvpa_sst_utils.py:235, in do_forced_choice(dataset, normalization, get_predict_and_prob)
#     232     test_X=(test_X-voxel_mean)/voxel_sd
#     233     #print("normalizing")
# --> 235 predict_y, y_class_match, sklearn_clf = get_predict_and_prob(train_X,train_y,test_X,test_y)
#     238 #need to label the output of the probability as CorrectStop and CorrectGo based on the classnames
#     239 #iterate through each class
#     240 proba_dict = {}
#
# File /gpfs/projects/sanlab/shared/DEV/DEV_scripts/fMRI/ml/SST/mvpa_sst_utils.py:196, in do_SVC(train_X, train_y, test_X, test_y)
#     188 sklearn_clf = SVC(probability=True)
#     190 #create the classifier with a probability function
#     191 #https://mmuratarat.github.io/2019-10-12/probabilistic-output-of-svm#:~:text=SVMs%20don't%20output%20probabilities,the%20output%20to%20class%20probabilities.&text=For%20many%20problems%2C%20it%20is,of%20certainty%20about%20the%20answer.
#     192 #we don't need this I'm doing my own probability estimate
#     193 #hmmm, is this why the model is performing so well? the tuning?
#     194 #sklearn_clf = CalibratedClassifierCV(clf_svc)
#     195 #train
# --> 196 sklearn_clf.fit(train_X, train_y)
#     198 #get the _probability_ we fall into each class
#     199 predict_y_prob = sklearn_clf.predict_proba(test_X)
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/svm/_base.py:190, in BaseLibSVM.fit(self, X, y, sample_weight)
#     188     check_consistent_length(X, y)
#     189 else:
# --> 190     X, y = self._validate_data(
#     191         X,
#     192         y,
#     193         dtype=np.float64,
#     194         order="C",
#     195         accept_sparse="csr",
#     196         accept_large_sparse=False,
#     197     )
#     199 y = self._validate_targets(y)
#     201 sample_weight = np.asarray(
#     202     [] if sample_weight is None else sample_weight, dtype=np.float64
#     203 )
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# --> 581         X, y = check_X_y(X, y, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/utils/validation.py:964, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     961 if y is None:
#     962     raise ValueError("y cannot be None")
# --> 964 X = check_array(
#     965     X,
#     966     accept_sparse=accept_sparse,
#     967     accept_large_sparse=accept_large_sparse,
#     968     dtype=dtype,
#     969     order=order,
#     970     copy=copy,
#     971     force_all_finite=force_all_finite,
#     972     ensure_2d=ensure_2d,
#     973     allow_nd=allow_nd,
#     974     ensure_min_samples=ensure_min_samples,
#     975     ensure_min_features=ensure_min_features,
#     976     estimator=estimator,
#     977 )
#     979 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     981 check_consistent_length(X, y)
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/utils/validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# KeyboardInterrupt:

# %%
forced_choice_results['sample_wise']

# %%
total_score = np.mean(list(forced_choice_results['group_wise'].values()))
total_score

# %% [markdown]
# Alright--and how about if we don't do the forced-choice?

# %%
prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])

# %%
print(prediction)
print(forced_choice_prediction)

# %% [markdown]
# ## masks

# %% [markdown]
# We get the same file this time, but we apply a mask before doing learning.

# %%
from generic_utils import *

# %%
## additional masks

all_masks = get_all_masks(ml_data_folderpath)

# %%
for mask_name in all_masks['mask_name']:
#    mask_value = all_masks[mask_name]
    print(mask_name,end=", ")
# Out:
# planning_association-test_z_FDR_0.01, executive function_association-test_z_FDR_0.01, response inhibition_association-test_z_FDR_0.01, inhibition_association-test_z_FDR_0.01, error_association-test_z_FDR_0.01, harvardoxford-cortical_prob_Frontal Orbital Cortex, harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars opercularis, harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars triangularis,

# %% [markdown]
# ### try out one mask

# %%
brain_data_filepath = "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_conditions_84subs_correct_cond_harvardoxford-cortical_prob_Frontal Orbital Cortex.pkl"

#brain_data_filepath = "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_conditions_84subs_correct_cond_harvardoxford-cortical_prob_Insular Cortex.pkl"
#brain_data_filepath = '/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_conditions_84subs_correct_cond_response inhibition_association-test_z_FDR_0.01.pkl'

# %%
with open(brain_data_filepath, 'rb') as pkl_file:
    Brain_Data_allsubs = pickle.load(pkl_file)

Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)

# %%
Brain_Data_allsubs[0].samples
# Out:
# array([[ 1.0382861 ,  1.0452528 ,  1.1514504 , ...,  0.7481537 ,
#          0.5825023 , -0.31958684]], dtype=float32)

# %%
masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)

# %%
from nilearn import plotting

plotting.plot_stat_map(masked_preview,vmax=18)
# Out:
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/nilearn/plotting/img_plotting.py:348: FutureWarning: Default resolution of the MNI template will change from 2mm to 1mm in version 0.10.0
#   anat_img = load_mni152_template()
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)

# %%
from mvpa2.mappers.flatten import mask_mapper
import nibabel as nib

# %%
Brain_Data_allsubs.samples[np.isnan(Brain_Data_allsubs.samples)]=0

# %%
sum(sum(np.isnan(Brain_Data_allsubs[0,:].samples)))
# Out:
# 0

# %%
Brain_Data_allsubs[0,:].samples
# Out:
# array([[ 1.0382861 ,  1.0452528 ,  1.1514504 , ...,  0.7481537 ,
#          0.5825023 , -0.31958684]], dtype=float32)

# %%
forced_choice_results = do_forced_choice(Brain_Data_allsubs)
# Out:
# ..............................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [39], in <module>
# ----> 1 forced_choice_results = do_forced_choice(Brain_Data_allsubs)
#
# File /gpfs/projects/sanlab/shared/DEV/DEV_scripts/fMRI/ml/SST/mvpa_sst_utils.py:235, in do_forced_choice(dataset, normalization, get_predict_and_prob)
#     232     test_X=(test_X-voxel_mean)/voxel_sd
#     233     #print("normalizing")
# --> 235 predict_y, y_class_match, sklearn_clf = get_predict_and_prob(train_X,train_y,test_X,test_y)
#     238 #need to label the output of the probability as CorrectStop and CorrectGo based on the classnames
#     239 #iterate through each class
#     240 proba_dict = {}
#
# File /gpfs/projects/sanlab/shared/DEV/DEV_scripts/fMRI/ml/SST/mvpa_sst_utils.py:196, in do_SVC(train_X, train_y, test_X, test_y)
#     188 sklearn_clf = SVC(probability=True)
#     190 #create the classifier with a probability function
#     191 #https://mmuratarat.github.io/2019-10-12/probabilistic-output-of-svm#:~:text=SVMs%20don't%20output%20probabilities,the%20output%20to%20class%20probabilities.&text=For%20many%20problems%2C%20it%20is,of%20certainty%20about%20the%20answer.
#     192 #we don't need this I'm doing my own probability estimate
#     193 #hmmm, is this why the model is performing so well? the tuning?
#     194 #sklearn_clf = CalibratedClassifierCV(clf_svc)
#     195 #train
# --> 196 sklearn_clf.fit(train_X, train_y)
#     198 #get the _probability_ we fall into each class
#     199 predict_y_prob = sklearn_clf.predict_proba(test_X)
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/svm/_base.py:255, in BaseLibSVM.fit(self, X, y, sample_weight)
#     252     print("[LibSVM]", end="")
#     254 seed = rnd.randint(np.iinfo("i").max)
# --> 255 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     256 # see comment on the other call to np.iinfo in this file
#     258 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/svm/_base.py:315, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     302 libsvm.set_verbosity_wrap(self.verbose)
#     304 # we don't pass **self.get_params() to allow subclasses to
#     305 # add other parameters to __init__
#     306 (
#     307     self.support_,
#     308     self.support_vectors_,
#     309     self._n_support,
#     310     self.dual_coef_,
#     311     self.intercept_,
#     312     self._probA,
#     313     self._probB,
#     314     self.fit_status_,
# --> 315 ) = libsvm.fit(
#     316     X,
#     317     y,
#     318     svm_type=solver_type,
#     319     sample_weight=sample_weight,
#     320     class_weight=self.class_weight_,
#     321     kernel=kernel,
#     322     C=self.C,
#     323     nu=self.nu,
#     324     probability=self.probability,
#     325     degree=self.degree,
#     326     shrinking=self.shrinking,
#     327     tol=self.tol,
#     328     cache_size=self.cache_size,
#     329     coef0=self.coef0,
#     330     gamma=self._gamma,
#     331     epsilon=self.epsilon,
#     332     max_iter=self.max_iter,
#     333     random_seed=random_seed,
#     334 )
#     336 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])
print(prediction,forced_choice_prediction)

# %% [markdown]
# yikes, that does seem a bit too good. Particularly considering that the non-forced-choice rsults are also up really high. We shouldn't be seeing resutls this high! Let's see how it goes across all the masks I have chosen.

# %%
forced_choice_results_dict = {}
for m_i,m_r in all_masks.iterrows():
    mask_name=m_r['mask_name']
    brain_data_filepath = (
        "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_conditions_84subs_correct_cond_" +
        mask_name
        + ".pkl"
    )
    if os.path.exists(brain_data_filepath):
        with open(brain_data_filepath, 'rb') as pkl_file:
            Brain_Data_allsubs = pickle.load(pkl_file)
            
        print(mask_name)

        Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)
        
        print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))
        
        masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
        plotting.plot_stat_map(masked_preview,vmax=18)

        forced_choice_results = do_forced_choice(Brain_Data_allsubs)
        print("")
        
        prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
        forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])
        
        print(prediction,forced_choice_prediction)

        forced_choice_results_dict[mask_name]=forced_choice_results

# %% [markdown]
# ## normalization...

# %%
brain_data_filepath = ml_data_folderpath + '/SST/mvpa_Dataset_conditions_84subs_correct_cond.pkl'

# %%
results_filepath=ml_data_folderpath + "/SST/ttr_mvpa2_res_v3_conditions_84subs_twoclasses_wholebrain.pkl"
#results_filepath=ml_data_folderpath + "/SST/train_test_results_" + dataset_name + "_58subs_twoclasses_pfcmask_repeat1.pkl"

def decoderConstructor(*args, **kwargs):
    return(Decoder(scoring='accuracy',verbose=0, *args, **kwargs))


relevant_mask = None

# %% [markdown]
# ### across series, training data only

# %%
with open(brain_data_filepath, 'rb') as pkl_file:
    Brain_Data_allsubs = pickle.load(pkl_file)

    
Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)

# %%
Brain_Data_allsubs.samples.copy()
# Out:
# array([[ 0.7312383 ,  0.27183977, -0.09587598, ..., -0.9286324 ,
#          0.68275356, -0.1660184 ],
#        [-0.381091  , -0.41968623, -0.42312527, ..., -0.6829239 ,
#         -0.12775972, -0.3424021 ],
#        [-0.00422587, -0.6077599 , -0.9000941 , ..., -2.3298805 ,
#         -0.33732155, -1.3221407 ],
#        ...,
#        [ 0.41749677,  0.32663387,  0.26954317, ...,  0.38780513,
#         -0.2603853 ,  0.03476725],
#        [ 0.25094506, -0.56350684, -1.2193519 , ...,  0.9981551 ,
#          0.6138571 ,  0.8256795 ],
#        [ 0.03494082, -0.22820817, -0.46821654, ..., -0.01853149,
#         -0.21609281, -0.10853325]], dtype=float32)

# %%
print(np.mean(Brain_Data_allsubs.samples,axis=0))
# Out:
# [ 1.1773757e-08  0.0000000e+00 -7.3585982e-09 ... -1.1773757e-08
#   6.6227386e-08  2.0604075e-08]

# %%
print(np.std(Brain_Data_allsubs.samples,axis=0))
# Out:
# [1.        1.0000001 1.        ... 1.        1.        0.9999999]

# %%
do_forced_choice(Brain_Data_allsubs,normalization="train_set_based")
# Out:
# .................................................................................
# {'sample_wise':        chunk     target_y       pred_y pred_y_forced_choice  \
#  0   DEV005_1    CorrectGo    CorrectGo            CorrectGo
#  1   DEV005_1  CorrectStop  CorrectStop          CorrectStop
#  0   DEV006_1    CorrectGo    CorrectGo            CorrectGo
#  1   DEV006_1  CorrectStop  CorrectStop          CorrectStop
#  0   DEV010_1    CorrectGo    CorrectGo            CorrectGo
#  ..       ...          ...          ...                  ...
#  1   DEV216_1  CorrectStop  CorrectStop          CorrectStop
#  0   DEV217_1    CorrectGo    CorrectGo            CorrectGo
#  1   DEV217_1  CorrectStop  CorrectStop          CorrectStop
#  0   DEV218_1    CorrectGo    CorrectGo            CorrectGo
#  1   DEV218_1  CorrectStop  CorrectStop          CorrectStop
#
#      pred_prob_CorrectGo  pred_prob_CorrectStop
#  0              0.928721               0.071279
#  1              0.148201               0.851799
#  0              0.974001               0.025999
#  1              0.248213               0.751787
#  0              0.969462               0.030538
#  ..                  ...                    ...
#  1              0.257557               0.742443
#  0              0.924387               0.075613
#  1              0.088072               0.911928
#  0              0.526234               0.473766
#  1              0.057398               0.942602
#
#  [162 rows x 6 columns],
#  'group_wise': {'DEV005_1': 1.0,
#   'DEV006_1': 1.0,
#   'DEV010_1': 1.0,
#   'DEV011_1': 1.0,
#   'DEV013_1': 1.0,
#   'DEV014_1': 1.0,
#   'DEV015_1': 1.0,
#   'DEV016_1': 1.0,
#   'DEV017_1': 1.0,
#   'DEV018_1': 1.0,
#   'DEV019_1': 1.0,
#   'DEV020_1': 1.0,
#   'DEV021_1': 1.0,
#   'DEV022_1': 1.0,
#   'DEV023_1': 1.0,
#   'DEV024_1': 1.0,
#   'DEV026_1': 1.0,
#   'DEV027_1': 1.0,
#   'DEV028_1': 1.0,
#   'DEV029_1': 1.0,
#   'DEV030_1': 1.0,
#   'DEV034_1': 1.0,
#   'DEV035_1': 1.0,
#   'DEV036_1': 1.0,
#   'DEV039_1': 1.0,
#   'DEV040_1': 1.0,
#   'DEV041_1': 1.0,
#   'DEV042_1': 1.0,
#   'DEV043_1': 1.0,
#   'DEV046_1': 1.0,
#   'DEV047_1': 1.0,
#   'DEV048_1': 1.0,
#   'DEV049_1': 1.0,
#   'DEV050_1': 1.0,
#   'DEV051_1': 1.0,
#   'DEV052_1': 1.0,
#   'DEV053_1': 1.0,
#   'DEV055_1': 0.0,
#   'DEV056_1': 1.0,
#   'DEV057_1': 1.0,
#   'DEV058_1': 1.0,
#   'DEV059_1': 1.0,
#   'DEV060_1': 1.0,
#   'DEV062_1': 1.0,
#   'DEV064_1': 1.0,
#   'DEV067_1': 1.0,
#   'DEV068_1': 1.0,
#   'DEV069_1': 1.0,
#   'DEV071_1': 1.0,
#   'DEV073_1': 1.0,
#   'DEV074_1': 1.0,
#   'DEV076_1': 1.0,
#   'DEV077_1': 1.0,
#   'DEV079_1': 1.0,
#   'DEV083_1': 1.0,
#   'DEV084_1': 1.0,
#   'DEV085_1': 1.0,
#   'DEV086_1': 1.0,
#   'DEV087_1': 1.0,
#   'DEV089_1': 1.0,
#   'DEV097_1': 1.0,
#   'DEV105_1': 1.0,
#   'DEV107_1': 1.0,
#   'DEV135_1': 1.0,
#   'DEV141_1': 1.0,
#   'DEV145_1': 1.0,
#   'DEV157_1': 1.0,
#   'DEV158_1': 1.0,
#   'DEV159_1': 1.0,
#   'DEV164_1': 1.0,
#   'DEV169_1': 1.0,
#   'DEV171_1': 1.0,
#   'DEV173_1': 1.0,
#   'DEV177_1': 1.0,
#   'DEV186_1': 1.0,
#   'DEV197_1': 1.0,
#   'DEV206_1': 1.0,
#   'DEV215_1': 1.0,
#   'DEV216_1': 1.0,
#   'DEV217_1': 1.0,
#   'DEV218_1': 1.0}}

# %% [markdown]
# ### across series, whole set

# %%
with open(brain_data_filepath, 'rb') as pkl_file:
    Brain_Data_allsubs = pickle.load(pkl_file)

    
Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)

# %%
def bd_mean_across_images_per_voxel(bd):
    voxel_mean = np.mean(bd.samples,axis=0)
    voxel_sd = np.std(bd.samples,axis=0)
    bd.samples = (bd.samples-voxel_mean)/voxel_sd
    return(bd)

# %%
Brain_Data_allsubs = bd_mean_across_images_per_voxel(Brain_Data_allsubs)

# %%
norm_across_whole_set = do_forced_choice(Brain_Data_allsubs)
# Out:
# .................................................................................

# %%
def get_pred_fcp(x):
    prediction = np.mean(x['sample_wise']['target_y']==x['sample_wise']['pred_y'])
    forced_choice_prediction = np.mean(x['sample_wise']['target_y']==x['sample_wise']['pred_y_forced_choice'])
    return(prediction,forced_choice_prediction)

# %%
get_pred_fcp(norm_across_whole_set)
# Out:
# (0.9506172839506173, 0.9876543209876543)

# %% [markdown]
# ## across each image

# %%
with open(brain_data_filepath, 'rb') as pkl_file:
    Brain_Data_allsubs = pickle.load(pkl_file)

    
Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)

# %%
def bd_mean_across_voxels_per_img(bd):
    img_mean = np.mean(bd.samples,axis=1,keepdims=True)
    img_sd = np.std(bd.samples,axis=1,keepdims=True)
    bd.samples = (bd.samples-img_mean)/img_sd
    return(bd)

# %%
Brain_Data_allsubs = bd_mean_across_voxels_per_img(Brain_Data_allsubs)

# %%
norm_across_each_img = do_forced_choice(Brain_Data_allsubs)
# Out:
# .................................................................................

# %%
prediction = np.mean(norm_across_each_img['sample_wise']['target_y']==norm_across_each_img['sample_wise']['pred_y'])
forced_choice_prediction = np.mean(norm_across_each_img['sample_wise']['target_y']==norm_across_each_img['sample_wise']['pred_y_forced_choice'])

# %%
prediction, forced_choice_prediction

# %% [markdown]
# ## neural similarity

# %% [markdown]
# Previously we used neural similarity. this learner is actually more accurate, and what's more, we get a numeric probability which will be helpful.
#
# Firstly, how can we re-eimplemnt the correlation I've already done?

# %% [markdown]
# def get_bd(brain_data_filepath,ns1,ns2,relevant_mask,condition1_name = 'PostError_similarity',condition2_name = 'PostCorrect_similarity',similarity_method='correlation'):
#     bd=pickle.load(open(brain_data_filepath,'rb'))
#
#     if relevant_mask is None:
#         relevant_mask = nlt.Brain_Data(ns1).mask
#     print("applying mask")
#     bd_to_measure = bd.apply_mask(relevant_mask)
#     #bd_PostError=bd[bd.X.condition_label=="CorrectGoFollowingFailedStop"]
#
#     #bd.X.condition_label.value_counts()
#
#     print("getting similarity 1")
#     #bd.X[condition1_name] = (bd_to_measure.similarity(ns1))
#     bd.X[condition1_name] = (nlt.Brain_Data(ns1).similarity(bd_to_measure,similarity_method))
#     print("getting similarity 2")
#     #bd.X[condition2_name] = (bd_to_measure.similarity(ns2))
#     bd.X[condition2_name] = (nlt.Brain_Data(ns2).similarity(bd_to_measure,similarity_method))
#
#     return(bd)

# %%
forced_choice_results['sample_wise'].rename({'chunk':'chunks'},axis=1,inplace=True)

# %%
from visualization import visualize_corr

classifier = forced_choice_results['classifier']
sample_wise_results = forced_choice_results['sample_wise']
cs_cs_prob = sample_wise_results.loc[sample_wise_results.target_y=='CorrectStop']

individual_differences['subj_wave'] = individual_differences.subject+"_"+individual_differences.wave.astype(str)
full_dataset_cs = individual_differences.merge(cs_cs_prob,how='outer',left_on='subj_wave',right_on='chunks')

visualize_corr('bf_1','pred_prob_CorrectStop',full_dataset_cs)
# Out:
# pred_prob_CorrectStop
# r=-0.25; p-value=0.0332
# rho=-0.27; p-value=0.0210

# %%
import math

# %%
not_na_vals = np.isnan(full_dataset_cs.pred_prob_CorrectStop)==False
log_vals = [math.log(1-x) for x in (full_dataset_cs.pred_prob_CorrectStop[not_na_vals])]
full_dataset_cs.loc[not_na_vals,'pred_prob_CorrectStop_inv_ln']=log_vals

# %%
", ".join(individual_differences)
# Out:
# 'subject, cancer_promoting_minus_preventing_FCI, cancer_promoting_minus_preventing_FFQ, cancer_promoting_minus_preventing_craved_FCI, cancer_promoting_minus_preventing_craved_FFQ, cancer_promoting_minus_preventing_liked_FCI, cancer_promoting_minus_preventing_liked_FFQ, cancer_promoting_FCI, cancer_promoting_FFQ, cancer_preventing_FCI, cancer_preventing_FFQ, BSCS, cSES, EDM, BIS_11, PCS, RS, TRSQ, bf_1, weight_0, height_0, birthsex, age365, bmi_0, bmi_1, bmi, bf_1_controlled, bf_1_bsexnormedzs, ACES_sum, ACES_household_dysfunction, ACES_neglectful_parenting, ACES_abuse, ACES_divorced_separated, BFI_agreeableness, BFI_conscientiousness, BFI_extraversion, BFI_neuroticism, BFI_openness, DEMO_mcarthur_social_standing, IMI_effort_importance, IMI_interest_enjoyment, IMI_perceived_choice, IMI_perceived_competence, IMI_value_usefulness, IPAQ_moderateminutes, IPAQ_sittinghours, IPAQ_vigorousminutes, IPAQ_walkingminutes, NCS_get_job_done, NCS_deliberating_issues, NCS_prefer_complex, NCS_prefer_little_thought, NCS_intellectual_task, NCS_relief_not_satisfaction, NCS_like_responsibility, NCS_new_solutions_to_problems, NCS_avoid_depth, NCS_tasks_little_thought, NCS_think_minimally, NCS_satisfaction_in_deliberating, NCS_small_daily_projects, NCS_solve_puzzles, NCS_total, NCS_thinking_not_exciting, NCS_abstract_thinking, NCS_thought_appealing, NCS_thinking_not_fun, PLAN_cognitive_strategies, PLAN_temporal_orientation, PLAN_mental_forecasting, RMQ_assessment, RMQ_lie, RMQ_locomotion, RTFS_factor_1, RTFS_factor_2, SRHI_sum, SRHI_healthy, SRHI_unhealthy, TESQ_E_avoidance_of_temptations, TESQ_E_goal_deliberation, TESQ_E_distraction, TESQ_E_goal_and_rule_setting, TESQ_E_sum, TESQ_E_controlling_temptations, TESQ_E_suppression, education_own, zipcode_median_income_acs, household_income_level_medamount, household_income_per_person, ses_aggregate, SST_CorrectGo, SST_CorrectStop, SST_Cue, SST_FailedGo, SST_FailedStop, SST_prop_successful_stops, SST_reaction_time, SST_go_trial_reaction_time, SST_GRTint, SST_GRTmean, SST_GRTmedian, SST_GRTquant, SST_NRCount, SST_PctInhib, SST_SSD, SST_SSRT, SST_SSRTint, SST_SSRTquant, ROC_Crave_Look, ROC_Crave_Regulate, ROC_Neutral_Look, ROC_No Crave_Look, ROC_Crave_Regulate_Minus_Look, ROC_Crave_Minus_Neutral, ROC_Crave_Minus_NoCrave, WTP_healthy, WTP_unhealthy, WTP_unhealthy_minus_healthy, SRHI_healthy_minus_unhealthy, RTFS_f1_minus_f2, IPAQ_walkingMETminutes, IPAQ_moderateMETminutes, IPAQ_vigorousMETminutes, IPAQ_total_METminutes, IPAQ_MET_kCal, birthsex_factor, wave, subj_wave'

# %%
visualize_corr('TESQ_E_sum','pred_prob_CorrectStop',full_dataset_cs)
# Out:
# pred_prob_CorrectStop
# r=-0.05; p-value=0.6831
# rho=0.12; p-value=0.3031

# %%
visualize_corr('TESQ_E_sum','pred_prob_CorrectStop_inv_ln',full_dataset_cs)
# Out:
# pred_prob_CorrectStop_inv_ln
# r=-0.04; p-value=0.7057
# rho=-0.12; p-value=0.3031

# %%
visualize_corr('bf_1','pred_prob_CorrectStop_inv_ln',full_dataset_cs)
# Out:
# pred_prob_CorrectStop_inv_ln
# r=0.28; p-value=0.0154
# rho=0.27; p-value=0.0210

# %% [markdown]
# Next to do:
# 1. Consider re-implementing LinearSVM and getting similarity rather than this probability measure
# 2. Visualize for all the other values.

# %% [markdown]
# Now we've decoupled the learner from the framework where we apply it, we can pass in any arbitrary learner. It just has to output:
#
# 1. predictions
# 2. prediction confidence
# 3. the classifier itself

# %% [markdown]
# ### Re-implementing v3
#
# This is a useful sanity check, becuase it's helpufl to try and explain why we're doing so much  better than rpeviously.

# %%
def do_LinearSVC(train_X,train_y,test_X,test_y):
    sklearn_clf = LinearSVC(penalty='l2', max_iter=1e4)
    #same as v3, my nilearn learner integrated with nltools
    #https://nilearn.github.io/modules/generated/nilearn.decoding.Decoder.html
    
    #sklearn_clf = CalibratedClassifierCV(clf_svc)
    #train
    sklearn_clf.fit(train_X, train_y)

    #get the _probability_ we fall into each class
    #we'll use similarity/correlation here.
    predict_y_prob = pearson_img_series(test_X,sklearn_clf.coef_)#sklearn_clf.predict_proba(test_X)
    predict_y = sklearn_clf.predict(test_X)
    return(predict_y,predict_y_prob,sklearn_clf)

# %%
linear_results_with_similarity = do_forced_choice(Brain_Data_allsubs,get_predict_and_prob=do_LinearSVC)
# Out:
# .................................................................................

# %%
forced_choice_results = linear_results_with_similarity

# %%
prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])

# %%
(prediction, forced_choice_prediction)
# Out:
# (0.691358024691358, 0.9012345679012346)

# %% [markdown]
# Formerly this was .85, .95, which was remarkable--we've now pretty clearly reproduced the result we were getting using nltools..
#
# However, after I updated it based on documentation here (https://nilearn.github.io/modules/generated/nilearn.decoding.Decoder.html) it performed less well. Not sure why the classifier is performing _less_ well in this setup than the former one - perhaps hte sort of normalization that I am doing on each side.

# %%
sample_wise_results = forced_choice_results['sample_wise']
cs_cs_prob = sample_wise_results.loc[sample_wise_results.target_y=='CorrectStop']

individual_differences['subj_wave'] = individual_differences.subject+"_"+individual_differences.wave.astype(str)
full_dataset_cs = individual_differences.merge(cs_cs_prob,how='outer',left_on='subj_wave',right_on='chunks')

# %%
from outlier_detection import *

# %%
full_dataset_cs = remove_selected_outliers_mvpa_tesq_study(
    full_dataset_cs,
    neural_measures = ['pred_prob_CorrectStop'])

# %%
visualize_corr('pred_prob_CorrectStop','bf_1',full_dataset_cs)
# Out:
# bf_1
# r=0.18; p-value=0.1408
# rho=0.17; p-value=0.1599

# %%
visualize_corr('pred_prob_CorrectStop','cancer_promoting_minus_preventing_FFQ',full_dataset_cs)
# Out:
# cancer_promoting_minus_preventing_FFQ
# r=-0.13; p-value=0.2441
# rho=-0.09; p-value=0.4030

# %%
visualize_corr('pred_prob_CorrectStop','TESQ_E_sum',full_dataset_cs)
# Out:
# TESQ_E_sum
# r=0.15; p-value=0.2096
# rho=0.13; p-value=0.2717

# %% [markdown]
# #### v3 mask

# %%
forced_choice_results_dict = {}
for m_i,m_r in all_masks.iterrows():
    mask_name=m_r['mask_name']
    brain_data_filepath = (
        "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_conditions_84subs_correct_cond_" +
        mask_name
        + ".pkl"
    )
    if os.path.exists(brain_data_filepath):
        with open(brain_data_filepath, 'rb') as pkl_file:
            Brain_Data_allsubs = pickle.load(pkl_file)
            
        print(mask_name)

        Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)
        
        print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))
        
        masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
        plotting.plot_stat_map(masked_preview,vmax=18)

        forced_choice_results = do_forced_choice(Brain_Data_allsubs,get_predict_and_prob=do_LinearSVC)
        print("")
        
        prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
        forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])
        
        print(prediction,forced_choice_prediction)

        forced_choice_results_dict[mask_name]=forced_choice_results
# Out:
# planning_association-test_z_FDR_0.01
# 2705.6913580246915
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.7407407407407407 0.9629629629629629
# executive function_association-test_z_FDR_0.01
# 99.72839506172839
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.7037037037037037 0.8641975308641975
# response inhibition_association-test_z_FDR_0.01
# 1958.111111111111
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.6851851851851852 0.9753086419753086
# inhibition_association-test_z_FDR_0.01
# 667.4135802469136
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.6172839506172839 0.8765432098765432
# harvardoxford-cortical_prob_Frontal Orbital Cortex
# 3142.7654320987654
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.6666666666666666 0.9135802469135802
# harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars opercularis
# 2416.91975308642
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.7098765432098766 0.9382716049382716
# harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars triangularis
# 2102.1666666666665
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.691358024691358 0.9012345679012346

# %%
for k in forced_choice_results_dict.keys():
    v=forced_choice_results_dict[k]
    print(k)
    print_forced_choice_results(
        v,
        individual_differences,
        ['pred_prob_CorrectStop'])
# Out:
# planning_association-test_z_FDR_0.01
# (0.7407407407407407, 0.9629629629629629)
# bf_1
# r=-0.35; p-value=0.0028
# rho=-0.35; p-value=0.0025
# cancer_promoting_minus_preventing_FFQ
# r=-0.09; p-value=0.4478
# rho=-0.05; p-value=0.6894
# TESQ_E_sum
# r=-0.08; p-value=0.5183
# rho=-0.09; p-value=0.4228
# executive function_association-test_z_FDR_0.01
# (0.7037037037037037, 0.8641975308641975)
# bf_1
# r=-0.13; p-value=0.2804
# rho=-0.04; p-value=0.7465
# cancer_promoting_minus_preventing_FFQ
# r=-0.07; p-value=0.5597
# rho=-0.07; p-value=0.5504
# TESQ_E_sum
# r=0.14; p-value=0.2309
# rho=0.15; p-value=0.1901
# response inhibition_association-test_z_FDR_0.01
# (0.6851851851851852, 0.9753086419753086)
# bf_1
# r=-0.19; p-value=0.1176
# rho=-0.22; p-value=0.0650
# cancer_promoting_minus_preventing_FFQ
# r=-0.01; p-value=0.9166
# rho=-0.03; p-value=0.8206
# TESQ_E_sum
# r=-0.15; p-value=0.1952
# rho=-0.15; p-value=0.2082
# inhibition_association-test_z_FDR_0.01
# (0.6172839506172839, 0.8765432098765432)
# bf_1
# r=-0.18; p-value=0.1208
# rho=-0.15; p-value=0.1974
# cancer_promoting_minus_preventing_FFQ
# r=-0.01; p-value=0.9267
# rho=-0.04; p-value=0.7113
# TESQ_E_sum
# r=-0.17; p-value=0.1410
# rho=-0.18; p-value=0.1322
# harvardoxford-cortical_prob_Frontal Orbital Cortex
# (0.6666666666666666, 0.9135802469135802)
# bf_1
# r=-0.15; p-value=0.2124
# rho=-0.14; p-value=0.2556
# cancer_promoting_minus_preventing_FFQ
# r=-0.16; p-value=0.1636
# rho=-0.17; p-value=0.1435
# TESQ_E_sum
# r=0.04; p-value=0.7654
# rho=0.08; p-value=0.5109
# harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars opercularis
# (0.7098765432098766, 0.9382716049382716)
# bf_1
# r=0.09; p-value=0.4585
# rho=0.08; p-value=0.4827
# cancer_promoting_minus_preventing_FFQ
# r=0.05; p-value=0.6884
# rho=0.07; p-value=0.5345
# TESQ_E_sum
# r=0.00; p-value=0.9742
# rho=-0.00; p-value=0.9861
# harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars triangularis
# (0.691358024691358, 0.9012345679012346)
# bf_1
# r=0.18; p-value=0.1408
# rho=0.17; p-value=0.1599
# cancer_promoting_minus_preventing_FFQ
# r=-0.13; p-value=0.2441
# rho=-0.09; p-value=0.4030
# TESQ_E_sum
# r=0.15; p-value=0.2096
# rho=0.13; p-value=0.2717

# %% [markdown]
# ## Apply the main analysis, looping through masks

# %%
forced_choice_results_dict = {}
for m_i,m_r in all_masks.iterrows():
    mask_name=m_r['mask_name']
    brain_data_filepath = (
        "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_conditions_84subs_correct_cond_" +
        mask_name
        + ".pkl"
    )
    if os.path.exists(brain_data_filepath):
        with open(brain_data_filepath, 'rb') as pkl_file:
            Brain_Data_allsubs = pickle.load(pkl_file)
            
        print(mask_name)

        Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)
        
        print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))
        
        masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
        plotting.plot_stat_map(masked_preview,vmax=18)
        plotting.show()
        forced_choice_results = do_forced_choice(Brain_Data_allsubs,get_predict_and_prob=do_SVC)
        print("")
        
        prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
        forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])
        
        forced_choice_results['sample_wise']['ln_inv_pred_prob_CorrectGo']=inv_log_transform(forced_choice_results['sample_wise']['pred_prob_CorrectGo'])
        forced_choice_results['sample_wise']['ln_inv_pred_prob_CorrectStop']=inv_log_transform(forced_choice_results['sample_wise']['pred_prob_CorrectStop'])


        
        print(prediction,forced_choice_prediction)

        forced_choice_results_dict[mask_name]=forced_choice_results
        print_forced_choice_results(
            forced_choice_results,
            individual_differences,
            ['ln_inv_pred_prob_CorrectStop'])
# Out:
# planning_association-test_z_FDR_0.01
# 2705.6913580246915
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.9320987654320988 0.9876543209876543
# (0.9320987654320988, 0.9876543209876543)
#      ln_inv_pred_prob_CorrectStop
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                       -2.384658
# 4                       -2.315528
# ..                            ...
# 196                     -3.092546
# 197                           NaN
# 198                           NaN
# 199                           NaN
# 200                     -3.353519
#
# [201 rows x 1 columns]
# bf_1
# r=0.29; p-value=0.0139
# rho=0.30; p-value=0.0097
# cancer_promoting_minus_preventing_FFQ
# r=0.09; p-value=0.4467
# rho=0.13; p-value=0.2452
# TESQ_E_sum
# r=-0.06; p-value=0.5803
# rho=-0.15; p-value=0.1992
# executive function_association-test_z_FDR_0.01
# 99.72839506172839
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.9135802469135802 0.9753086419753086
# (0.9135802469135802, 0.9753086419753086)
#      ln_inv_pred_prob_CorrectStop
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                       -2.433404
# 4                       -1.668112
# ..                            ...
# 196                     -1.347880
# 197                           NaN
# 198                           NaN
# 199                           NaN
# 200                     -3.537067
#
# [201 rows x 1 columns]
# bf_1
# r=0.30; p-value=0.0110
# rho=0.32; p-value=0.0062
# cancer_promoting_minus_preventing_FFQ
# r=0.06; p-value=0.6210
# rho=0.07; p-value=0.5560
# TESQ_E_sum
# r=-0.08; p-value=0.5071
# rho=-0.13; p-value=0.2511
# response inhibition_association-test_z_FDR_0.01
# 1958.111111111111
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.9382716049382716 0.9753086419753086
# (0.9382716049382716, 0.9753086419753086)
#      ln_inv_pred_prob_CorrectStop
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                       -3.382822
# 4                       -2.811562
# ..                            ...
# 196                     -1.979105
# 197                           NaN
# 198                           NaN
# 199                           NaN
# 200                     -3.582056
#
# [201 rows x 1 columns]
# bf_1
# r=0.18; p-value=0.1220
# rho=0.19; p-value=0.1014
# cancer_promoting_minus_preventing_FFQ
# r=0.11; p-value=0.3114
# rho=0.23; p-value=0.0417
# TESQ_E_sum
# r=-0.08; p-value=0.5222
# rho=-0.12; p-value=0.3137
# inhibition_association-test_z_FDR_0.01
# 667.4135802469136
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.9259259259259259 0.9753086419753086
# (0.9259259259259259, 0.9753086419753086)
#      ln_inv_pred_prob_CorrectStop
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                       -2.681331
# 4                       -3.021033
# ..                            ...
# 196                     -2.283747
# 197                           NaN
# 198                           NaN
# 199                           NaN
# 200                     -3.602644
#
# [201 rows x 1 columns]
# bf_1
# r=0.19; p-value=0.1024
# rho=0.18; p-value=0.1303
# cancer_promoting_minus_preventing_FFQ
# r=0.19; p-value=0.0841
# rho=0.30; p-value=0.0063
# TESQ_E_sum
# r=-0.12; p-value=0.2940
# rho=-0.20; p-value=0.0877
# harvardoxford-cortical_prob_Frontal Orbital Cortex
# 3142.7654320987654
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.9506172839506173 0.9753086419753086
# (0.9506172839506173, 0.9753086419753086)
#      ln_inv_pred_prob_CorrectStop
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                       -2.946788
# 4                       -2.720058
# ..                            ...
# 196                     -2.606764
# 197                           NaN
# 198                           NaN
# 199                           NaN
# 200                     -2.711274
#
# [201 rows x 1 columns]
# bf_1
# r=0.24; p-value=0.0437
# rho=0.21; p-value=0.0715
# cancer_promoting_minus_preventing_FFQ
# r=0.15; p-value=0.1900
# rho=0.20; p-value=0.0765
# TESQ_E_sum
# r=-0.21; p-value=0.0766
# rho=-0.29; p-value=0.0114
# harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars opercularis
# 2416.91975308642
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.9320987654320988 0.9753086419753086
# (0.9320987654320988, 0.9753086419753086)
#      ln_inv_pred_prob_CorrectStop
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                       -2.735293
# 4                       -2.368246
# ..                            ...
# 196                     -2.991615
# 197                           NaN
# 198                           NaN
# 199                           NaN
# 200                     -2.445522
#
# [201 rows x 1 columns]
# bf_1
# r=0.06; p-value=0.6432
# rho=0.07; p-value=0.5564
# cancer_promoting_minus_preventing_FFQ
# r=0.06; p-value=0.6207
# rho=0.12; p-value=0.2813
# TESQ_E_sum
# r=-0.10; p-value=0.3890
# rho=-0.20; p-value=0.0812
# harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars triangularis
# 2102.1666666666665
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................
# 0.9444444444444444 0.9753086419753086
# (0.9444444444444444, 0.9753086419753086)
#      ln_inv_pred_prob_CorrectStop
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                       -2.693219
# 4                       -2.317886
# ..                            ...
# 196                     -4.100829
# 197                           NaN
# 198                           NaN
# 199                           NaN
# 200                     -2.384806
#
# [201 rows x 1 columns]
# bf_1
# r=0.17; p-value=0.1516
# rho=0.17; p-value=0.1499
# cancer_promoting_minus_preventing_FFQ
# r=0.18; p-value=0.1183
# rho=0.25; p-value=0.0265
# TESQ_E_sum
# r=0.03; p-value=0.7921
# rho=-0.05; p-value=0.6431

# %%
print("whole brain")
brain_data_filepath = (
    "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_conditions_84subs_correct_cond.pkl"
)

with open(brain_data_filepath, 'rb') as pkl_file:
    Brain_Data_allsubs = pickle.load(pkl_file)

Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)

print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))

#masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
#plotting.plot_stat_map(masked_preview,vmax=18)

forced_choice_results = do_forced_choice(Brain_Data_allsubs,get_predict_and_prob=do_SVC)


sample_wise_results = forced_choice_results['sample_wise']
prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])

forced_choice_results['sample_wise']['ln_inv_pred_prob_CorrectGo']=inv_log_transform(sample_wise_results['pred_prob_CorrectGo'])
forced_choice_results['sample_wise']['ln_inv_pred_prob_CorrectStop']=inv_log_transform(sample_wise_results['pred_prob_CorrectStop'])



print(prediction,forced_choice_prediction)

forced_choice_results_dict[mask_name]=forced_choice_results
print_forced_choice_results(
    forced_choice_results,
    individual_differences,
    ['ln_inv_pred_prob_CorrectStop'])
# Out:
# whole brain
# 127427.37037037036
# .................................................................................0.9506172839506173 0.9876543209876543
# (0.9506172839506173, 0.9876543209876543)
#      ln_inv_pred_prob_CorrectStop
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                       -2.421457
# 4                       -1.676303
# ..                            ...
# 196                     -2.815866
# 197                           NaN
# 198                           NaN
# 199                           NaN
# 200                     -3.778719
#
# [201 rows x 1 columns]
# bf_1
# r=0.22; p-value=0.0663
# rho=0.24; p-value=0.0449
# cancer_promoting_minus_preventing_FFQ
# r=0.21; p-value=0.0698
# rho=0.15; p-value=0.1770
# TESQ_E_sum
# r=-0.13; p-value=0.2682
# rho=-0.17; p-value=0.1515

# %% [markdown]
# # Loop through correlation items

# %%
brain_data_filepath = "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_conditions_84subs_correct_cond_harvardoxford-cortical_prob_Frontal Orbital Cortex.pkl"

results_filepath=ml_data_folderpath + "/SST/ttr_mvpa2_res_v5_conditions_84subs_twoclasses_wholebrain.pkl"
#results_filepath=ml_data_folderpath + "/SST/train_test_results_" + dataset_name + "_58subs_twoclasses_pfcmask_repeat1.pkl"

relevant_mask = None

# %%
if os.path.exists(results_filepath):
    with open(results_filepath, 'rb') as pkl_file:
        forced_choice_results = pickle.load(pkl_file)
else:
    forced_choice_results = do_forced_choice(Brain_Data_allsubs)
    with open(results_filepath, 'wb') as pkl_file:
        pickle.dump(forced_choice_results,file=pkl_file)

# %% [markdown]
# Now--loop through the items, and then loop through masks

# %%
prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])

# %%
import math
def inv_log_transform(series):
    series=series.copy()
    not_na_vals = np.isnan(series)==False
    log_vals = [math.log(1-x) for x in (series[not_na_vals])]
    series[not_na_vals] = log_vals
    return(log_vals)


sample_wise_results = forced_choice_results['sample_wise']   
sample_wise_results['ln_inv_pred_prob_CorrectGo']=inv_log_transform(sample_wise_results['pred_prob_CorrectGo'])
sample_wise_results['ln_inv_pred_prob_CorrectStop']=inv_log_transform(sample_wise_results['pred_prob_CorrectStop'])

# %%
sample_wise_results
# Out:
#       chunks     target_y       pred_y pred_y_forced_choice  \
# 0   DEV005_1    CorrectGo    CorrectGo            CorrectGo
# 1   DEV005_1  CorrectStop  CorrectStop          CorrectStop
# 0   DEV006_1    CorrectGo    CorrectGo            CorrectGo
# 1   DEV006_1  CorrectStop  CorrectStop          CorrectStop
# 0   DEV010_1    CorrectGo    CorrectGo            CorrectGo
# ..       ...          ...          ...                  ...
# 1   DEV216_1  CorrectStop  CorrectStop          CorrectStop
# 0   DEV217_1    CorrectGo    CorrectGo            CorrectGo
# 1   DEV217_1  CorrectStop  CorrectStop          CorrectStop
# 0   DEV218_1    CorrectGo  CorrectStop            CorrectGo
# 1   DEV218_1  CorrectStop  CorrectStop          CorrectStop
#
#     pred_prob_CorrectGo  pred_prob_CorrectStop  ln_inv_pred_prob_CorrectGo  \
# 0              0.950488               0.049512                   -3.005542
# 1              0.088201               0.911799                   -0.092336
# 0              0.992946               0.007054                   -4.954176
# 1              0.179542               0.820458                   -0.197892
# 0              0.989892               0.010108                   -4.594446
# ..                  ...                    ...                         ...
# 1              0.236497               0.763503                   -0.269838
# 0              0.984806               0.015194                   -4.186848
# 1              0.050841               0.949159                   -0.052179
# 0              0.517527               0.482473                   -0.728830
# 1              0.024794               0.975206                   -0.025106
#
#     ln_inv_pred_prob_CorrectStop
# 0                      -0.050780
# 1                      -2.428138
# 0                      -0.007079
# 1                      -1.717347
# 0                      -0.010159
# ..                           ...
# 1                      -1.441819
# 0                      -0.015311
# 1                      -2.979056
# 0                      -0.658694
# 1                      -3.697172
#
# [162 rows x 8 columns]

# %%
correct_go_probs = sample_wise_results.loc[
    sample_wise_results.target_y=='CorrectGo',
    ['chunks','ln_inv_pred_prob_CorrectGo','ln_inv_pred_prob_CorrectStop']
]
correct_go_probs.columns = ["CorGo_"+ cname for cname in correct_go_probs.columns]

correct_stop_probs = sample_wise_results.loc[
    sample_wise_results.target_y=='CorrectStop',
    ['chunks','ln_inv_pred_prob_CorrectGo','ln_inv_pred_prob_CorrectStop']
]
correct_stop_probs.columns = ["CorStop_"+ cname for cname in correct_stop_probs.columns]

cor_go_stop = correct_go_probs.merge(correct_stop_probs,left_on='CorGo_chunks',right_on='CorStop_chunks')
cor_go_stop.drop('CorStop_chunks',inplace=True,axis=1)
cor_go_stop.rename({'CorGo_chunks':'chunks'},inplace=True,axis=1)

# %%
cor_go_stop
# Out:
#       chunks  CorGo_ln_inv_pred_prob_CorrectGo  \
# 0   DEV005_1                         -3.005542
# 1   DEV006_1                         -4.954176
# 2   DEV010_1                         -4.594446
# 3   DEV011_1                         -2.224268
# 4   DEV013_1                         -2.633643
# ..       ...                               ...
# 76  DEV206_1                         -2.953129
# 77  DEV215_1                         -4.177023
# 78  DEV216_1                         -5.519182
# 79  DEV217_1                         -4.186848
# 80  DEV218_1                         -0.728830
#
#     CorGo_ln_inv_pred_prob_CorrectStop  CorStop_ln_inv_pred_prob_CorrectGo  \
# 0                            -0.050780                           -0.092336
# 1                            -0.007079                           -0.197892
# 2                            -0.010159                           -0.088889
# 3                            -0.114453                           -0.060926
# 4                            -0.074526                           -0.019450
# ..                                 ...                                 ...
# 76                           -0.053587                           -0.028089
# 77                           -0.015463                           -0.043914
# 78                           -0.004017                           -0.269838
# 79                           -0.015311                           -0.052179
# 80                           -0.658694                           -0.025106
#
#     CorStop_ln_inv_pred_prob_CorrectStop
# 0                              -2.428138
# 1                              -1.717347
# 2                              -2.464482
# 3                              -2.828398
# 4                              -3.949606
# ..                                   ...
# 76                             -3.586405
# 77                             -3.147388
# 78                             -1.441819
# 79                             -2.979056
# 80                             -3.697172
#
# [81 rows x 5 columns]

# %%
individual_differences['subj_wave'] = individual_differences.subject+"_"+individual_differences.wave.astype(str)
full_dataset_cs = individual_differences.merge(cor_go_stop,how='outer',left_on='subj_wave',right_on='chunks')

# %%
full_dataset_cs = remove_selected_outliers_mvpa_study(full_dataset_cs)

# %%
for neural_var in ['CorGo_ln_inv_pred_prob_CorrectGo','CorStop_ln_inv_pred_prob_CorrectStop']:
    display(Markdown("### " + neural_var))
    for correlate in ['BFI_extraversion','RMQ_locomotion','ses_aggregate','PLAN_cognitive_strategies','SST_SSRT','BIS_11','BSCS','TESQ_E_suppression', 'TESQ_E_avoidance_of_temptations', 
                      'TESQ_E_goal_deliberation', 'TESQ_E_controlling_temptations', 'TESQ_E_distraction', 'TESQ_E_goal_and_rule_setting',
                     'EDM','RS','TRSQ','ROC_Crave_Regulate_Minus_Look','SRHI_unhealthy','bf_1']:
        visualize_corr(neural_var,correlate,full_dataset_cs)
# Out:
# ### CorGo_ln_inv_pred_prob_CorrectGo
# BFI_extraversion
# r=0.08; p-value=0.5156
# rho=0.07; p-value=0.5319
# RMQ_locomotion
# r=0.30; p-value=0.0072
# rho=0.30; p-value=0.0068
# ses_aggregate
# r=0.16; p-value=0.2516
# rho=0.17; p-value=0.2054
# PLAN_cognitive_strategies
# r=0.25; p-value=0.0308
# rho=0.26; p-value=0.0253
# SST_SSRT
# r=0.05; p-value=0.6910
# rho=0.04; p-value=0.7020
# BIS_11
# r=-0.16; p-value=0.1536
# rho=-0.14; p-value=0.2238
# BSCS
# r=0.24; p-value=0.0354
# rho=0.24; p-value=0.0368
# TESQ_E_suppression
# r=0.04; p-value=0.7543
# rho=0.04; p-value=0.7250
# TESQ_E_avoidance_of_temptations
# r=0.12; p-value=0.3177
# rho=0.17; p-value=0.1389
# TESQ_E_goal_deliberation
# r=0.21; p-value=0.0668
# rho=0.20; p-value=0.0866
# TESQ_E_controlling_temptations
# r=0.10; p-value=0.3923
# rho=0.07; p-value=0.5354
# TESQ_E_distraction
# r=0.17; p-value=0.1384
# rho=0.18; p-value=0.1307
# TESQ_E_goal_and_rule_setting
# r=0.17; p-value=0.1549
# rho=0.15; p-value=0.2043
# EDM
# r=0.06; p-value=0.6139
# rho=0.12; p-value=0.2824
# RS
# r=0.06; p-value=0.6132
# rho=0.04; p-value=0.7270
# TRSQ
# r=0.20; p-value=0.0822
# rho=0.22; p-value=0.0549
# ROC_Crave_Regulate_Minus_Look
# r=-0.07; p-value=0.5789
# rho=-0.06; p-value=0.6297
# SRHI_unhealthy
# r=-0.17; p-value=0.1535
# rho=-0.14; p-value=0.2414
# bf_1
# r=-0.28; p-value=0.0175
# rho=-0.33; p-value=0.0049
# ### CorStop_ln_inv_pred_prob_CorrectStop
# BFI_extraversion
# r=-0.10; p-value=0.3946
# rho=-0.10; p-value=0.3811
# RMQ_locomotion
# r=-0.22; p-value=0.0516
# rho=-0.25; p-value=0.0294
# ses_aggregate
# r=-0.03; p-value=0.8369
# rho=-0.01; p-value=0.9224
# PLAN_cognitive_strategies
# r=-0.17; p-value=0.1386
# rho=-0.21; p-value=0.0750
# SST_SSRT
# r=0.15; p-value=0.2008
# rho=0.17; p-value=0.1413
# BIS_11
# r=0.16; p-value=0.1525
# rho=0.19; p-value=0.0979
# BSCS
# r=-0.14; p-value=0.2307
# rho=-0.18; p-value=0.1355
# TESQ_E_suppression
# r=0.00; p-value=0.9778
# rho=-0.02; p-value=0.8663
# TESQ_E_avoidance_of_temptations
# r=0.02; p-value=0.8673
# rho=0.00; p-value=0.9955
# TESQ_E_goal_deliberation
# r=-0.26; p-value=0.0231
# rho=-0.32; p-value=0.0055
# TESQ_E_controlling_temptations
# r=-0.15; p-value=0.2013
# rho=-0.17; p-value=0.1521
# TESQ_E_distraction
# r=-0.05; p-value=0.6734
# rho=-0.04; p-value=0.7273
# TESQ_E_goal_and_rule_setting
# r=-0.14; p-value=0.2365
# rho=-0.15; p-value=0.1951
# EDM
# r=0.05; p-value=0.6315
# rho=0.00; p-value=0.9831
# RS
# r=-0.15; p-value=0.1952
# rho=-0.05; p-value=0.6871
# TRSQ
# r=-0.21; p-value=0.0790
# rho=-0.22; p-value=0.0614
# ROC_Crave_Regulate_Minus_Look
# r=0.10; p-value=0.4321
# rho=0.06; p-value=0.6342
# SRHI_unhealthy
# r=0.11; p-value=0.3688
# rho=0.11; p-value=0.3621
# bf_1
# r=0.23; p-value=0.0577
# rho=0.24; p-value=0.0430

# %% [markdown]
# ## Contrast between CorrectStop and CorrectGo...

# %%
#", ".join(sa_to_df(Brain_Data_allsubs.sa).columns)

# %%
forced_choice_results_dict = {}
for m_i,m_r in all_masks.iterrows():
    mask_name=m_r['mask_name']
    brain_data_filepath = (
        "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_conditions_84subs_correct_stop_go_contrast_" +
        mask_name
        + ".pkl"
    )
    if os.path.exists(brain_data_filepath):

        target='SST_SSRT'

        with open(brain_data_filepath, 'rb') as pkl_file:
            Brain_Data_allsubs = pickle.load(pkl_file)

        Brain_Data_allsubs = Brain_Data_allsubs[np.isnan(Brain_Data_allsubs.sa[target].value)==False]

        print(mask_name)

        Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs,target,standardize=True)

        print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))

        masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
        plotting.plot_stat_map(masked_preview,vmax=18)
        plotting.show()
        forced_choice_results = do_regression(Brain_Data_allsubs,get_predict_and_prob=do_Ridge)
        print("")

#             prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
#             forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])

#             forced_choice_results['sample_wise']['ln_inv_pred_prob_CorrectGo']=inv_log_transform(sample_wise_results['pred_prob_CorrectGo'])
#             forced_choice_results['sample_wise']['ln_inv_pred_prob_CorrectStop']=inv_log_transform(sample_wise_results['pred_prob_CorrectStop'])



        #print(prediction,forced_choice_prediction)

        forced_choice_results_dict[mask_name]=forced_choice_results
        print_regression_results(forced_choice_results,['mae'])
# Out:
# planning_association-test_z_FDR_0.01
# 1685.1518987341772
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ...............................................................................
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'IPAQ_vigorousMETminutes', 'IPAQ_total_METminutes', 'IPAQ_MET_kCal',
#        'birthsex_factor', 'wave', 'subj_wave', 'chunks', 'target_y', 'pred_y',
#        'mae'],
#       dtype='object', length=132)
# bf_1
# r=0.08; p-value=0.5002
# rho=0.04; p-value=0.7340
# cancer_promoting_minus_preventing_FFQ
# r=0.30; p-value=0.0075
# rho=0.32; p-value=0.0039
# TESQ_E_sum
# r=0.04; p-value=0.7492
# rho=-0.02; p-value=0.8590
# executive function_association-test_z_FDR_0.01
# 77.50632911392405
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ...............................................................................
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'IPAQ_vigorousMETminutes', 'IPAQ_total_METminutes', 'IPAQ_MET_kCal',
#        'birthsex_factor', 'wave', 'subj_wave', 'chunks', 'target_y', 'pred_y',
#        'mae'],
#       dtype='object', length=132)
# bf_1
# r=0.05; p-value=0.7022
# rho=-0.03; p-value=0.8363
# cancer_promoting_minus_preventing_FFQ
# r=0.08; p-value=0.4746
# rho=0.11; p-value=0.3731
# TESQ_E_sum
# r=-0.01; p-value=0.9440
# rho=0.01; p-value=0.9522
# response inhibition_association-test_z_FDR_0.01
# 1291.1645569620252
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ...............................................................................
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'IPAQ_vigorousMETminutes', 'IPAQ_total_METminutes', 'IPAQ_MET_kCal',
#        'birthsex_factor', 'wave', 'subj_wave', 'chunks', 'target_y', 'pred_y',
#        'mae'],
#       dtype='object', length=132)
# bf_1
# r=0.13; p-value=0.2991
# rho=0.06; p-value=0.6568
# cancer_promoting_minus_preventing_FFQ
# r=0.17; p-value=0.1467
# rho=0.18; p-value=0.1179
# TESQ_E_sum
# r=-0.11; p-value=0.3876
# rho=-0.08; p-value=0.5041
# inhibition_association-test_z_FDR_0.01
# 436.0886075949367
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ...............................................................................
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'IPAQ_vigorousMETminutes', 'IPAQ_total_METminutes', 'IPAQ_MET_kCal',
#        'birthsex_factor', 'wave', 'subj_wave', 'chunks', 'target_y', 'pred_y',
#        'mae'],
#       dtype='object', length=132)
# bf_1
# r=-0.00; p-value=0.9830
# rho=-0.08; p-value=0.5060
# cancer_promoting_minus_preventing_FFQ
# r=0.04; p-value=0.7474
# rho=0.09; p-value=0.4479
# TESQ_E_sum
# r=-0.17; p-value=0.1448
# rho=-0.21; p-value=0.0728
# harvardoxford-cortical_prob_Frontal Orbital Cortex
# 2847.012658227848
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ...............................................................................
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'IPAQ_vigorousMETminutes', 'IPAQ_total_METminutes', 'IPAQ_MET_kCal',
#        'birthsex_factor', 'wave', 'subj_wave', 'chunks', 'target_y', 'pred_y',
#        'mae'],
#       dtype='object', length=132)
# bf_1
# r=0.05; p-value=0.6852
# rho=0.03; p-value=0.8389
# cancer_promoting_minus_preventing_FFQ
# r=0.14; p-value=0.2242
# rho=0.19; p-value=0.0947
# TESQ_E_sum
# r=-0.00; p-value=0.9902
# rho=-0.06; p-value=0.6249
# harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars opercularis
# 1471.4303797468353
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ...............................................................................
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'IPAQ_vigorousMETminutes', 'IPAQ_total_METminutes', 'IPAQ_MET_kCal',
#        'birthsex_factor', 'wave', 'subj_wave', 'chunks', 'target_y', 'pred_y',
#        'mae'],
#       dtype='object', length=132)
# bf_1
# r=0.09; p-value=0.4700
# rho=0.09; p-value=0.4461
# cancer_promoting_minus_preventing_FFQ
# r=0.15; p-value=0.1912
# rho=0.09; p-value=0.4369
# TESQ_E_sum
# r=-0.33; p-value=0.0057
# rho=-0.30; p-value=0.0124
# harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars triangularis
# 1538.620253164557
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ...............................................................................
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'IPAQ_vigorousMETminutes', 'IPAQ_total_METminutes', 'IPAQ_MET_kCal',
#        'birthsex_factor', 'wave', 'subj_wave', 'chunks', 'target_y', 'pred_y',
#        'mae'],
#       dtype='object', length=132)
# bf_1
# r=0.01; p-value=0.9557
# rho=-0.04; p-value=0.7644
# cancer_promoting_minus_preventing_FFQ
# r=0.04; p-value=0.7313
# rho=0.05; p-value=0.6446
# TESQ_E_sum
# r=-0.10; p-value=0.3993
# rho=-0.15; p-value=0.2086

# %%
brain_data_filepath = (
    "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_conditions_84subs_correct_stop_go_contrast.pkl"
)

target='SST_SSRT'

with open(brain_data_filepath, 'rb') as pkl_file:
    Brain_Data_allsubs = pickle.load(pkl_file)

Brain_Data_allsubs = Brain_Data_allsubs[np.isnan(Brain_Data_allsubs.sa[target].value)==False]

print(mask_name)

Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs,target,standardize=True)

print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))

masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
plotting.plot_stat_map(masked_preview,vmax=18)
plotting.show()
forced_choice_results = do_regression(Brain_Data_allsubs,get_predict_and_prob=do_Ridge)
print("")


forced_choice_results_dict[mask_name]=forced_choice_results
print_regression_results(forced_choice_results,['mae'])
# Out:
# harvardoxford-cortical_prob_Inferior Frontal Gyrus, pars triangularis
# 108520.02531645569
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ...
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.3466e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.55211e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.27406e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.11435e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.01995e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.22174e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.1365e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.29197e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.37195e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.14587e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.3401e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.4792e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.13074e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.51638e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.10771e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.42884e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.16605e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.24135e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.27849e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.17444e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.51536e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.03639e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.32662e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.47439e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.263e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.14526e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.24325e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.36e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.33944e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.41993e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.16458e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.16236e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.27412e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.81581e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.41303e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.29131e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.22977e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.99843e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.44902e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.88395e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.28041e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.1843e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.78835e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.16703e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.57511e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.42558e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.4367e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.63866e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.40746e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.23091e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.29997e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.22218e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.05825e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.30593e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.46081e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.24517e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.43528e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.42074e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.99017e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.1692e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.41775e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.22715e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.34319e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.15753e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.10879e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.24447e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.27121e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.22157e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.27406e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.06374e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.056e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.48659e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.05474e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.16402e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.22216e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.14187e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.29135e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.13431e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'IPAQ_vigorousMETminutes', 'IPAQ_total_METminutes', 'IPAQ_MET_kCal',
#        'birthsex_factor', 'wave', 'subj_wave', 'chunks', 'target_y', 'pred_y',
#        'mae'],
#       dtype='object', length=132)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.32289e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.00275e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# bf_1
# r=0.11; p-value=0.3682
# rho=0.06; p-value=0.6085
# cancer_promoting_minus_preventing_FFQ
# r=0.24; p-value=0.0355
# rho=0.25; p-value=0.0234
# TESQ_E_sum
# r=-0.14; p-value=0.2277
# rho=-0.20; p-value=0.0828

# %% [markdown]
# # v5 on PES
#
# Here we're going to run the same "version 5" analysis as above, but on the PES contrast instead. Should be straightforward to replicate.

# %%
pes_vars_of_interest  =['RTFS_factor_1','RTFS_factor_2','RTFS_f1_minus_f2', 'SST_PostErrorSlowW1_median','SST_PostErrorSlowW1_mean','SST_pes_mean_limited','FFQ_v2_Mean_Weighted_Nutrient_Density']

# %% [markdown]
# ## discriminability

# %%
from generic_utils import *
## additional masks

all_masks = get_failure_masks(ml_data_folderpath)

# %% [markdown]
# ### masked, conditions separate

# %%
all_masks
# Out:
#                                            mask_name  \
# 0        negative affect_association-test_z_FDR_0.01
# 1     emotion regulation_association-test_z_FDR_0.01
# 2  harvardoxford-cortical_prob_Frontal Medial Cortex
# 3      negative emotions_association-test_z_FDR_0.01
# 4       self referential_association-test_z_FDR_0.01
# 5  harvardoxford-cortical_prob_Frontal Orbital Co...
# 6  harvardoxford-cortical_prob_Cingulate Gyrus, a...
#
#                                        mask_filepath  thresh
# 0  /gpfs/projects/sanlab/shared/DEV/nonbids_data/...     0.1
# 1  /gpfs/projects/sanlab/shared/DEV/nonbids_data/...     0.1
# 2  /gpfs/projects/sanlab/shared/DEV/nonbids_data/...     0.1
# 3  /gpfs/projects/sanlab/shared/DEV/nonbids_data/...     0.1
# 4  /gpfs/projects/sanlab/shared/DEV/nonbids_data/...     0.1
# 5  /gpfs/projects/sanlab/shared/DEV/nonbids_data/...    10.0
# 6  /gpfs/projects/sanlab/shared/DEV/nonbids_data/...    10.0

# %%
forced_choice_results_dict = {}
for m_i,m_r in all_masks.iterrows():
    mask_name=m_r['mask_name']
    brain_data_filepath = (
        "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_posterror_conditions_84subs_post_stop_cg_" +
        mask_name
        + ".pkl"
    )
    print(brain_data_filepath)
    if os.path.exists(brain_data_filepath):
        with open(brain_data_filepath, 'rb') as pkl_file:
            Brain_Data_allsubs = pickle.load(pkl_file)
            
        print(mask_name)

        Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)
        
        print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))
        
        masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
        plotting.plot_stat_map(masked_preview,vmax=18)
        plotting.show()
        forced_choice_results = do_forced_choice(Brain_Data_allsubs,get_predict_and_prob=do_SVC)
        
        
        prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
        forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])
        
        forced_choice_results['sample_wise']['ln_inv_pred_prob_CGAfterCS']=inv_log_transform(forced_choice_results['sample_wise']['pred_prob_CorrectGoFollowingCorrectStop'])
        forced_choice_results['sample_wise']['ln_inv_pred_prob_CGAfterFS']=inv_log_transform(forced_choice_results['sample_wise']['pred_prob_CorrectGoFollowingFailedStop'])

        print(prediction,forced_choice_prediction)

        forced_choice_results_dict[mask_name]=forced_choice_results

        
        print_forced_choice_results(
            forced_choice_results,
            individual_differences,
            ['ln_inv_pred_prob_CGAfterCS'],
            behavioral_measures = pes_vars_of_interest,
            target_y='CorrectGoFollowingCorrectStop')
        print_forced_choice_results(
            forced_choice_results,
            individual_differences,
            ['ln_inv_pred_prob_CGAfterFS'],
            behavioral_measures = pes_vars_of_interest,
            target_y='CorrectGoFollowingFailedStop')
# Out:
# /gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_posterror_conditions_84subs_post_stop_cg_negative affect_association-test_z_FDR_0.01.pkl
# negative affect_association-test_z_FDR_0.01
# 1170.0925925925926
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .................................................................................0.6234567901234568 0.35802469135802467
# (0.6234567901234568, 0.35802469135802467)
# RTFS_factor_1
# r=0.10; p-value=0.4966
# rho=0.17; p-value=0.2740
# RTFS_factor_2
# r=-0.10; p-value=0.5196
# rho=-0.06; p-value=0.7129
# RTFS_f1_minus_f2
# r=0.26; p-value=0.0983
# rho=0.21; p-value=0.1670
# SST_PostErrorSlowW1_median
# r=0.05; p-value=0.7262
# rho=0.06; p-value=0.6790
# SST_PostErrorSlowW1_mean
# r=-0.05; p-value=0.7418
# rho=-0.06; p-value=0.6871
# SST_pes_mean_limited
# r=-0.04; p-value=0.7546
# rho=-0.09; p-value=0.5097
# FFQ_v2_Mean_Weighted_Nutrient_Density
# r=0.13; p-value=0.2949
# rho=0.10; p-value=0.4541
# (0.6234567901234568, 0.35802469135802467)
# RTFS_factor_1
# r=-0.08; p-value=0.5656
# rho=-0.08; p-value=0.5813
# RTFS_factor_2
# r=0.01; p-value=0.9653
# rho=-0.02; p-value=0.8937
# RTFS_f1_minus_f2
# r=-0.08; p-value=0.5835
# rho=-0.04; p-value=0.8074
# SST_PostErrorSlowW1_median
# r=-0.11; p-value=0.4010
# rho=-0.19; p-value=0.1438
# SST_PostErrorSlowW1_mean
# r=-0.20; p-value=0.1151
# rho=-0.21; p-value=0.1007
# SST_pes_mean_limited
# r=-0.07; p-value=0.5643
# rho=-0.07; p-value=0.6007
# FFQ_v2_Mean_Weighted_Nutrient_Density
# r=-0.22; p-value=0.0653
# rho=-0.15; p-value=0.2010
# /gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_posterror_conditions_84subs_post_stop_cg_emotion regulation_association-test_z_FDR_0.01.pkl
# emotion regulation_association-test_z_FDR_0.01
# 913.3456790123457
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [44], in <module>
#      18 print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))
#      20 masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
# ---> 21 plotting.plot_stat_map(masked_preview,vmax=18)
#      22 plotting.show()
#      23 forced_choice_results = do_forced_choice(Brain_Data_allsubs,get_predict_and_prob=do_SVC)
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/nilearn/plotting/img_plotting.py:988, in plot_stat_map(stat_map_img, bg_img, cut_coords, output_file, display_mode, colorbar, cbar_tick_format, figure, axes, title, threshold, annotate, draw_cross, black_bg, cmap, symmetric_cbar, dim, vmax, resampling_interpolation, **kwargs)
#     980 stat_map_img = _utils.check_niimg_3d(stat_map_img, dtype='auto')
#     982 cbar_vmin, cbar_vmax, vmin, vmax = _get_colorbar_and_data_ranges(
#     983     _safe_get_data(stat_map_img, ensure_finite=True),
#     984     vmax,
#     985     symmetric_cbar,
#     986     kwargs)
# --> 988 display = _plot_img_with_bg(
#     989     img=stat_map_img, bg_img=bg_img, cut_coords=cut_coords,
#     990     output_file=output_file, display_mode=display_mode,
#     991     figure=figure, axes=axes, title=title, annotate=annotate,
#     992     draw_cross=draw_cross, black_bg=black_bg, threshold=threshold,
#     993     bg_vmin=bg_vmin, bg_vmax=bg_vmax, cmap=cmap, vmin=vmin, vmax=vmax,
#     994     colorbar=colorbar, cbar_tick_format=cbar_tick_format,
#     995     cbar_vmin=cbar_vmin, cbar_vmax=cbar_vmax,
#     996     resampling_interpolation=resampling_interpolation, **kwargs)
#     998 return display
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/nilearn/plotting/img_plotting.py:197, in _plot_img_with_bg(img, bg_img, cut_coords, output_file, display_mode, colorbar, figure, axes, title, threshold, annotate, draw_cross, black_bg, vmin, vmax, bg_vmin, bg_vmax, interpolation, display_factory, cbar_vmin, cbar_vmax, cbar_tick_format, brain_color, decimals, **kwargs)
#     195 if bg_img is not None:
#     196     bg_img = _utils.check_niimg_3d(bg_img)
# --> 197     display.add_overlay(bg_img,
#     198                         vmin=bg_vmin, vmax=bg_vmax,
#     199                         cmap=plt.cm.gray, interpolation=interpolation)
#     201 if img is not None and img is not False:
#     202     display.add_overlay(new_img_like(img, data, affine),
#     203                         threshold=threshold, interpolation=interpolation,
#     204                         colorbar=colorbar, vmin=vmin, vmax=vmax,
#     205                         cbar_tick_format=cbar_tick_format,
#     206                         **kwargs)
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/nilearn/plotting/displays/_slicers.py:265, in BaseSlicer.add_overlay(self, img, threshold, colorbar, cbar_tick_format, **kwargs)
#     262 # Make sure that add_overlay shows consistent default behavior
#     263 # with plot_stat_map
#     264 kwargs.setdefault('interpolation', 'nearest')
# --> 265 ims = self._map_show(img, type='imshow', threshold=threshold, **kwargs)
#     267 # `ims` can be empty in some corner cases, look at test_img_plotting.test_outlier_cut_coords.
#     268 if colorbar and ims:
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/nilearn/plotting/displays/_slicers.py:344, in BaseSlicer._map_show(self, img, type, resampling_interpolation, threshold, **kwargs)
#     341 threshold = float(threshold) if threshold is not None else None
#     343 if threshold is not None:
# --> 344     data = _safe_get_data(img, ensure_finite=True)
#     345     if threshold == 0:
#     346         data = np.ma.masked_equal(data, 0, copy=False)
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/nilearn/_utils/niimg.py:55, in _safe_get_data(img, ensure_finite, copy_data)
#      51     img = copy.deepcopy(img)
#      53 # typically the line below can double memory usage
#      54 # that's why we invoke a forced call to the garbage collector
# ---> 55 gc.collect()
#      57 data = _get_data(img)
#      58 if ensure_finite:
#
# KeyboardInterrupt:

# %% [markdown]
# ### whole brain, conditions separate

# %%
print("whole brain")
brain_data_filepath = (
    "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_posterror_conditions_84subs_post_stop_cg.pkl"
)

with open(brain_data_filepath, 'rb') as pkl_file:
    Brain_Data_allsubs = pickle.load(pkl_file)

Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs)

print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))

#masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
#plotting.plot_stat_map(masked_preview,vmax=18)

forced_choice_results = do_forced_choice(Brain_Data_allsubs,get_predict_and_prob=do_SVC)


sample_wise_results = forced_choice_results['sample_wise']
prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])


print_forced_choice_results(
    forced_choice_results,
    individual_differences,
    ['ln_inv_pred_prob_CGAfterCS'],
    behavioral_measures = pes_vars_of_interest,
    target_y='CorrectGoFollowingCorrectStop')
print_forced_choice_results(
    forced_choice_results,
    individual_differences,
    ['ln_inv_pred_prob_CGAfterFS'],
    behavioral_measures = pes_vars_of_interest,
    target_y='CorrectGoFollowingFailedStop')

print(prediction,forced_choice_prediction)
# Out:
# whole brain
# 122853.14814814815
# .....................................................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [45], in <module>
#      11 print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))
#      13 #masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
#      14 #plotting.plot_stat_map(masked_preview,vmax=18)
# ---> 16 forced_choice_results = do_forced_choice(Brain_Data_allsubs,get_predict_and_prob=do_SVC)
#      19 sample_wise_results = forced_choice_results['sample_wise']
#      20 prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
#
# File /gpfs/projects/sanlab/shared/DEV/DEV_scripts/fMRI/ml/SST/mvpa_sst_utils.py:235, in do_forced_choice(dataset, normalization, get_predict_and_prob)
#     232     test_X=(test_X-voxel_mean)/voxel_sd
#     233     #print("normalizing")
# --> 235 predict_y, y_class_match, sklearn_clf = get_predict_and_prob(train_X,train_y,test_X,test_y)
#     238 #need to label the output of the probability as CorrectStop and CorrectGo based on the classnames
#     239 #iterate through each class
#     240 proba_dict = {}
#
# File /gpfs/projects/sanlab/shared/DEV/DEV_scripts/fMRI/ml/SST/mvpa_sst_utils.py:196, in do_SVC(train_X, train_y, test_X, test_y)
#     188 sklearn_clf = SVC(probability=True)
#     190 #create the classifier with a probability function
#     191 #https://mmuratarat.github.io/2019-10-12/probabilistic-output-of-svm#:~:text=SVMs%20don't%20output%20probabilities,the%20output%20to%20class%20probabilities.&text=For%20many%20problems%2C%20it%20is,of%20certainty%20about%20the%20answer.
#     192 #we don't need this I'm doing my own probability estimate
#     193 #hmmm, is this why the model is performing so well? the tuning?
#     194 #sklearn_clf = CalibratedClassifierCV(clf_svc)
#     195 #train
# --> 196 sklearn_clf.fit(train_X, train_y)
#     198 #get the _probability_ we fall into each class
#     199 predict_y_prob = sklearn_clf.predict_proba(test_X)
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/svm/_base.py:255, in BaseLibSVM.fit(self, X, y, sample_weight)
#     252     print("[LibSVM]", end="")
#     254 seed = rnd.randint(np.iinfo("i").max)
# --> 255 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     256 # see comment on the other call to np.iinfo in this file
#     258 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/svm/_base.py:315, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     302 libsvm.set_verbosity_wrap(self.verbose)
#     304 # we don't pass **self.get_params() to allow subclasses to
#     305 # add other parameters to __init__
#     306 (
#     307     self.support_,
#     308     self.support_vectors_,
#     309     self._n_support,
#     310     self.dual_coef_,
#     311     self.intercept_,
#     312     self._probA,
#     313     self._probB,
#     314     self.fit_status_,
# --> 315 ) = libsvm.fit(
#     316     X,
#     317     y,
#     318     svm_type=solver_type,
#     319     sample_weight=sample_weight,
#     320     class_weight=self.class_weight_,
#     321     kernel=kernel,
#     322     C=self.C,
#     323     nu=self.nu,
#     324     probability=self.probability,
#     325     degree=self.degree,
#     326     shrinking=self.shrinking,
#     327     tol=self.tol,
#     328     cache_size=self.cache_size,
#     329     coef0=self.coef0,
#     330     gamma=self._gamma,
#     331     epsilon=self.epsilon,
#     332     max_iter=self.max_iter,
#     333     random_seed=random_seed,
#     334 )
#     336 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %% [markdown]
# ## PES contrast...

# %%
print("whole brain")
brain_data_filepath = (
    "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_posterror_conditions_84subs_post_stop_cg_contrast.pkl"
)

target='SST_pes_mean_limited'

with open(brain_data_filepath, 'rb') as pkl_file:
    Brain_Data_allsubs = pickle.load(pkl_file)

Brain_Data_allsubs = Brain_Data_allsubs[np.isnan(Brain_Data_allsubs.sa[target].value)==False]

print(mask_name)

Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs,target,standardize=True)

print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))

masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
plotting.plot_stat_map(masked_preview,vmax=18)
plotting.show()
forced_choice_results = do_regression(Brain_Data_allsubs,get_predict_and_prob=do_Ridge)
print("")


forced_choice_results_dict[mask_name]=forced_choice_results
print_regression_results(
    forced_choice_results,['mae'],
    [target])


prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])

print(prediction,forced_choice_prediction)
# Out:
# whole brain
# emotion regulation_association-test_z_FDR_0.01
# 131510.78787878787
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ...
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.45747e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.3864e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.39624e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.44474e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.44306e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.82022e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.5189e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.45122e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.81871e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.39293e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.63711e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.64581e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.56116e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.4974e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ...
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.53823e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.52875e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.78585e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.60025e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.6012e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.73376e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.46749e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.5119e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.23955e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.49616e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.55139e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.34081e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.30068e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.87874e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.5145e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.69449e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.56085e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.4755e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.46824e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.42316e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.5967e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.65153e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ...
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.37957e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.51924e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.72934e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.49086e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.13395e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.50092e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.50072e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.78394e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.54678e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.68681e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.24651e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.62456e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.37326e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.46149e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.58128e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.49894e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.86418e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.35088e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.62708e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.50725e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.22301e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.52753e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.2523e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.48796e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.34142e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.42141e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# .
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.40929e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.3919e-08): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <module>
#      23 print("")
#      26 forced_choice_results_dict[mask_name]=forced_choice_results
# ---> 27 print_regression_results(
#      28     forced_choice_results,['mae'],
#      29     [target])
#      32 prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y'])
#      33 forced_choice_prediction = np.mean(forced_choice_results['sample_wise']['target_y']==forced_choice_results['sample_wise']['pred_y_forced_choice'])
#
# File /gpfs/projects/sanlab/shared/DEV/DEV_scripts/fMRI/ml/SST/mvpa_sst_utils.py:339, in print_regression_results(forced_choice_results, neural_measures, behavioral_measures)
#     336     sample_wise_results = forced_choice_results['sample_wise']
#     337 #    cs_cs_prob = sample_wise_results.loc[sample_wise_results.target_y=='CorrectStop']
# --> 339     individual_differences['subj_wave'] = individual_differences.subject+"_"+individual_differences.wave.astype(str)
#     340     full_dataset_cs = individual_differences.merge(sample_wise_results,how='outer',left_on='subj_wave',right_on='chunks')
#     341     print(full_dataset_cs.columns)
#
# NameError: name 'individual_differences' is not defined

# %%
forced_choice_results_dict = {}
for m_i,m_r in all_masks.iterrows():
    mask_name=m_r['mask_name']
    brain_data_filepath = (
        "/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/ml/SST/mvpa_Dataset_posterror_conditions_84subs_post_stop_cg_contrast_" +
        mask_name
        + ".pkl"
    )
    
    if os.path.exists(brain_data_filepath):

        target='SST_pes_mean_limited'

        with open(brain_data_filepath, 'rb') as pkl_file:
            Brain_Data_allsubs = pickle.load(pkl_file)

        Brain_Data_allsubs = Brain_Data_allsubs[np.isnan(Brain_Data_allsubs.sa[target].value)==False]

        print(mask_name)

        Brain_Data_allsubs = setup_metadata(Brain_Data_allsubs,target,standardize=True)

        print(sum(sum(Brain_Data_allsubs.samples>0))/len(Brain_Data_allsubs.samples))

        masked_preview = unmask(Brain_Data_allsubs.samples[0], Brain_Data_allsubs.a['mask_nifti'].value)
        plotting.plot_stat_map(masked_preview,vmax=18)
        plotting.show()
        forced_choice_results = do_regression(Brain_Data_allsubs,get_predict_and_prob=do_Ridge)
        print("")

        forced_choice_results_dict[mask_name]=forced_choice_results
        print_regression_results(forced_choice_results,['mae'],[target])
# Out:
# negative affect_association-test_z_FDR_0.01
# 1204.3484848484848
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .....................
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.87853e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.48889e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.57349e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.22174e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.51387e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.39972e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.82911e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.49296e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.2444e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.8261e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.7345e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.34805e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.228e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.87174e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.03782e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.12454e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.07631e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.55009e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.74148e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.83436e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ...................
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.04161e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.24913e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.81707e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.97903e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.01057e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.66555e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.10598e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.76484e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.08914e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.57827e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.23941e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.31414e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.65851e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.82773e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.25739e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.28902e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.33354e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.0126e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.9648e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ...................
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.46849e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.29862e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.86217e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.82492e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.75648e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.52317e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.34714e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.30495e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.14227e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.7338e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.34586e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.08471e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.13911e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.06555e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.52764e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.99005e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.70268e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.17071e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# .......
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'FFQ_v2_Mean_Weighted_percent_daily_value',
#        'FFQ_v2_Mean_Dietary_Nutrient_Density', 'FFQ_v2_Mean_Energy_Density',
#        'FFQ_v2_Mean_Energy', 'wave', 'subj_wave', 'chunks', 'target_y',
#        'pred_y', 'mae'],
#       dtype='object', length=144)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.11242e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.074e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.36842e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.88923e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.67447e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.74522e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.6317e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.93068e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.02024e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# SST_pes_mean_limited
# r=0.33; p-value=0.0081
# rho=0.05; p-value=0.6707
# emotion regulation_association-test_z_FDR_0.01
# 972.560606060606
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# .........................................
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.22439e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.73137e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.6525e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.17102e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.10823e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.02191e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.18794e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.25409e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.12323e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.52466e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.74052e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.0612e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.09236e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.86872e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.39504e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.81756e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.42947e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.85996e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.50699e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.90929e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.42108e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.04451e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.16342e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.13636e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.3937e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.70333e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.7202e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.87523e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.07421e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.98229e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.58139e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.81436e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.15824e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.69879e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.80139e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.947e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.65456e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.92244e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.68922e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.11336e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# .........................
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'FFQ_v2_Mean_Weighted_percent_daily_value',
#        'FFQ_v2_Mean_Dietary_Nutrient_Density', 'FFQ_v2_Mean_Energy_Density',
#        'FFQ_v2_Mean_Energy', 'wave', 'subj_wave', 'chunks', 'target_y',
#        'pred_y', 'mae'],
#       dtype='object', length=144)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.63786e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.28901e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.4655e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.7742e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.6872e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.52617e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.56793e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.16213e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.5658e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.03042e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.04332e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.06466e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.84263e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.9806e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.04037e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.15199e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.84106e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.75019e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.7418e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.00834e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.2046e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.14112e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.44426e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.37925e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.85584e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.14416e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# SST_pes_mean_limited
# r=0.17; p-value=0.1979
# rho=0.06; p-value=0.6617
# harvardoxford-cortical_prob_Frontal Medial Cortex
# 1882.439393939394
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# ....................................
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.99985e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.07627e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.9876e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.74672e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.06756e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.71552e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=8.36424e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.52259e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.11821e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=6.7807e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=8.47125e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.27962e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.0659e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.11349e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=8.73346e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.00495e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.23245e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.94273e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=6.84084e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.48306e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.9772e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.31861e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.14739e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.16929e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=6.04208e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.30018e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.51049e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.73897e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.53249e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.82535e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.00351e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.25638e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# ..............................
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.06669e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.1097e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.45857e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.04338e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.73003e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.65617e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.29797e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=8.80412e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.9585e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.20282e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.8732e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=9.42388e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.80494e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.7748e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.92345e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.13092e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.09935e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.39458e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.76326e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.94888e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.37562e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.29952e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.67959e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.16316e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.44437e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.09131e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.91374e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.86814e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.7673e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.02649e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/bsmith16/.conda/envs/py3_mvpa/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=9.16542e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Index(['subject', 'cancer_promoting_minus_preventing_FCI',
#        'cancer_promoting_minus_preventing_FFQ',
#        'cancer_promoting_minus_preventing_craved_FCI',
#        'cancer_promoting_minus_preventing_craved_FFQ',
#        'cancer_promoting_minus_preventing_liked_FCI',
#        'cancer_promoting_minus_preventing_liked_FFQ', 'cancer_promoting_FCI',
#        'cancer_promoting_FFQ', 'cancer_preventing_FCI',
#        ...
#        'FFQ_v2_Mean_Weighted_percent_daily_value',
#        'FFQ_v2_Mean_Dietary_Nutrient_Density', 'FFQ_v2_Mean_Energy_Density',
#        'FFQ_v2_Mean_Energy', 'wave', 'subj_wave', 'chunks', 'target_y',
#        'pred_y', 'mae'],
#       dtype='object', length=144)
# SST_pes_mean_limited
# r=0.18; p-value=0.1699
# rho=0.11; p-value=0.4074

# %% [markdown]
# the mae is diverging in a way which suggests there is mae correlation with the variable itself, which isn't very meaningful.
