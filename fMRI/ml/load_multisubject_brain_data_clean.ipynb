# %%
import pandas as pd
import numpy as np
import os
import nltools as nlt
import nilearn as nil
import nibabel as nib
import warnings
import glob
import random
import pickle
from operator import itemgetter
import dev_wtp_io_utils

# %%
wtpw1_behavdesign_clean = pd.read_csv("../data/wtpw1_behavdesign_clean.csv")

# %%
test_train_df = pd.read_csv("../data/train_test_markers_20210601T183243.csv")

# %%
train_subjs = test_train_df.loc[test_train_df.SplitGroup=='Train','sub_label'].tolist()

# %%
def get_Brain_Data_for_sub(sub_label,behavdesign,betaseries_path='/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/fx/models/WTP/wave1/betaseries/'):
    return(dev_wtp_io_utils.get_Brain_Data_betas_for_sub(sub_label,behavdesign,betaseries_path))

# %% [markdown]
# ## Run subject group

# %%
train_subjs.sort()

bd_dict={}
for sl in train_subjs:
    print(sl)
    bd = get_Brain_Data_for_sub(sl,wtpw1_behavdesign_clean)
    bd_dict[sl]=bd
# Out:
# DEV001
# ...................................................................verified that all expected betas exist! Processing...caught 64 instances of the warning:
# NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
# ...imported data.
# DEV005
# ...................................................................verified that all expected betas exist! Processing...caught 64 instances of the warning:
# NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
# ...imported data.
# DEV006
# ...................................................................verified that all expected betas exist! Processing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0920805e381d> in <module>
# ...

# %%
Brain_Data_allsubs = list(bd_dict.values())[0]
for i in range(1,len(bd_dict.values())):
    print(i)
    val_to_append = list(bd_dict.values())[i]
    Brain_Data_allsubs= Brain_Data_allsubs.append(val_to_append)

# %%
with open('../data/Brain_Data_75subs.pkl', 'wb') as pkl_file:
    pickle.dump(Brain_Data_allsubs,pkl_file)

# %% [markdown]
# ### Specific subject check

# %%
pd.set_option('display.max_rows', 99)

# %%
subject_image_counts = wtpw1_behavdesign.subject.value_counts()
subject_image_counts = subject_image_counts.sort_index()
print(subject_image_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-48081865d0e3> in <module>
# ----> 1 subject_image_counts = wtpw1_behavdesign.subject.value_counts()
#       2 subject_image_counts = subject_image_counts.sort_index()
#       3 print(subject_image_counts)
#
# NameError: name 'wtpw1_behavdesign' is not defined

# %%
bd_dict={}
#for sl in sub_labels:
sl = 'DEV072'
print(sl)
bd = get_Brain_Data_for_sub(sl,wtpw1_behavdesign)
bd_dict[sl]=bd
# Out:
# DEV072
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a9ef5f9f416c> in <module>
#       3 sl = 'DEV072'
#       4 print(sl)
# ----> 5 bd = get_Brain_Data_for_sub(sl,wtpw1_behavdesign)
#       6 bd_dict[sl]=bd
#
# NameError: name 'wtpw1_behavdesign' is not defined

# %%
[subject_dir + b for b in subj_behav_design.beta]

# %%
#import them, but catch a very specific warning and don't show it because it gets annoying
#https://docs.python.org/3/library/warnings.html
with warnings.catch_warnings(record=True) as w:
    subj_data = nlt.Brain_Data([subject_dir + b for b in subj_behav_design.beta],
                              X=subj_behav_design)

# %%
na_inf_warn_count=0
for wi in w:
    if wi.message.args[0]!='NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.':
        warnings.warn(wi.message,type(wi))
    else:
        na_inf_warn_count+=1

if na_inf_warn_count>0:
    print("caught "+ str(na_inf_warn_count) + " instances of the warning:\n" + 
         'NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.')

print('...imported data.')
return(subj_data)

# %% [markdown]
# ### Run for 2s betas
#
# These are betas created specially for neural signature. They are just two seconds and they do NOT have a canonical hrf as a basis function - no basis function at all.

# %% [raw]
# train_subjs.sort()
#
# bd_dict={}
# #get the brain data from the beta files
# for sl in train_subjs:
#     print(sl)
#     bd = dev_wtp_io_utils.get_Brain_Data_betas_for_sub(
#         sl, wtpw1_behavdesign_clean,betaseries_path =
#         '/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/fx/models/WTP/wave1/betaseries_ns_no_hrf_from_spm/'
#     )
#     bd_dict[sl]=bd
#
# #now append into a concatenated brain data file
# Brain_Data_allsubs = list(bd_dict.values())[0]
# for i in range(1,len(bd_dict.values())):
#     print(i)
#     val_to_append = list(bd_dict.values())[i]
#     Brain_Data_allsubs= Brain_Data_allsubs.append(val_to_append)
#
# #dump
#
# with open('../data/Brain_Data_2sns_60subs.pkl', 'wb') as pkl_file:
#     pickle.dump(Brain_Data_allsubs,pkl_file)

# %% [markdown]
# ### 40 only

# %%
train_subjs.sort()

bd_dict={}
#get the brain data from the beta files
for sl in train_subjs[0:40]:
    print(sl)
    bd = dev_wtp_io_utils.get_Brain_Data_betas_for_sub(
        sl, wtpw1_behavdesign_clean,betaseries_path = 
        '/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/fx/models/WTP/wave1/betaseries_ns_no_hrf_from_spm/'
    )
    bd_dict[sl]=bd
    
#now append into a concatenated brain data file
Brain_Data_allsubs = list(bd_dict.values())[0]
for i in range(1,len(bd_dict.values())):
    print(i)
    val_to_append = list(bd_dict.values())[i]
    Brain_Data_allsubs= Brain_Data_allsubs.append(val_to_append)
    
#dump

with open('../data/Brain_Data_2sns_40subs.pkl', 'wb') as pkl_file:
    pickle.dump(Brain_Data_allsubs,pkl_file)
# Out:
# DEV001
# ...................................................................verified that all expected betas exist! Processing...caught 64 instances of the warning:
# NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
# ...imported data.
# DEV005
# ...................................................................verified that all expected betas exist! Processing...caught 64 instances of the warning:
# NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
# ...imported data.
# DEV006
# ...................................................................verified that all expected betas exist! Processing...caught 64 instances of the warning:
# NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
# ...imported data.
# DEV009
# ...

# %% [markdown]
# #### 30 only

# %%
train_subjs.sort()

bd_dict={}
#get the brain data from the beta files
for sl in train_subjs[0:30]:
    print(sl)
    bd = dev_wtp_io_utils.get_Brain_Data_betas_for_sub(
        sl, wtpw1_behavdesign_clean,betaseries_path = 
        '/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/fx/models/WTP/wave1/betaseries_ns/'
    )
    bd_dict[sl]=bd
    
#now append into a concatenated brain data file
Brain_Data_allsubs = list(bd_dict.values())[0]
for i in range(1,len(bd_dict.values())):
    print(i)
    val_to_append = list(bd_dict.values())[i]
    Brain_Data_allsubs= Brain_Data_allsubs.append(val_to_append)
    
#dump

with open('../data/Brain_Data_2sns_30subs.pkl', 'wb') as pkl_file:
    pickle.dump(Brain_Data_allsubs,pkl_file)
# Out:
# DEV001
# ...................................................................verified that all expected betas exist! Processing...caught 64 instances of the warning:
# NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
# ...imported data.
# DEV005
# ...................................................................verified that all expected betas exist! Processing...caught 64 instances of the warning:
# NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
# ...imported data.
# DEV006
# ...................................................................verified that all expected betas exist! Processing...caught 64 instances of the warning:
# NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
# ...imported data.
# DEV009
# ...

# %% [markdown]
# #### 2s betas with mean across each run for each response type
#
# This time we create a mean across response type...

# %%
sub_label = train_subjs[0]

# %%
sub_behav_design = wtpw1_behavdesign_clean[[s in sub_label for s in wtpw1_behavdesign_clean.subject]]

# %%
sub_behav_design
# Out:
#                 beta  type       task  event_id   isi_pre       onset  \
# 25     beta_0001.nii  run1  WTP betas         1  3.000000    6.136695
# 207    beta_0002.nii  run1  WTP betas         2  3.000000   18.787566
# 389    beta_0003.nii  run1  WTP betas         3  1.780283   30.205032
# 571    beta_0004.nii  run1  WTP betas         4  0.095117   39.939028
# 753    beta_0005.nii  run1  WTP betas         5  2.680966   52.256542
# ...              ...   ...        ...       ...       ...         ...
# 10763  beta_0075.nii  run4  WTP betas        12  0.925946  127.759576
# 10945  beta_0076.nii  run4  WTP betas        13  0.670865  138.043713
# 11127  beta_0077.nii  run4  WTP betas        14  0.859947  148.527772
# 11309  beta_0078.nii  run4  WTP betas        15  0.333113  158.478461
# 11491  beta_0079.nii  run4  WTP betas        16  1.421652  169.512455
#
#        duration                food_pic  food_num                cond  \
# ...

# %%
grouping_var_list=['response']
run_data_list = ['type','run','wave','subject']
grouped_subj_behavioral_design = sub_behav_design[run_data_list + grouping_var_list].drop_duplicates()

#now iterate through each group
for beta_group in grouped_subj_behavioral_design.iterrows():
    #get the betas in each group
    group_behav_design = grouped_subj_behavioral_design.merge(sub_behav_design,how='left')
    subj_data = nlt.Brain_Data([subject_dir + b for b in group_behav_design.beta],
                          X=group_behav_design)
    subj_raw_data_nii = nib.load(raw_filepath)
    
    

#grab the relevant files
#get the mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ea3df3f9833f> in <module>
#       7     #get the betas in each group
#       8     group_behav_design = grouped_subj_behavioral_design.merge(sub_behav_design,how='left')
# ----> 9     subj_data = nlt.Brain_Data([subject_dir + b for b in group_behav_design.beta],
#      10                           X=group_behav_design)
#      11     subj_raw_data_nii = nib.load(raw_filepath)
#
# <ipython-input-19-ea3df3f9833f> in <listcomp>(.0)
#       7     #get the betas in each group
#       8     group_behav_design = grouped_subj_behavioral_design.merge(sub_behav_design,how='left')
# ----> 9     subj_data = nlt.Brain_Data([subject_dir + b for b in group_behav_design.beta],
#      10                           X=group_behav_design)
#      11     subj_raw_data_nii = nib.load(raw_filepath)
#
# ...

# %%
grouped_subj_behavioral_design

# %%
design_grouped =

# %%
bd0 = dev_wtp_io_utils.get_Brain_Data_betas_for_sub(
        , wtpw1_behavdesign_clean,betaseries_path = 
        '/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/fx/models/WTP/wave1/betaseries_ns/'
    )
# Out:
# ...................................................................verified that all expected betas exist! Processing...caught 64 instances of the warning:
# NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
# ...imported data.

# %%
bd0.groupby()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-64d2f4623c30> in <module>
# ----> 1 bd0.groupby(bd0.X.response)
#
# ~/.conda/envs/neuralsignature/lib/python3.8/site-packages/nltools/data/brain_data.py in groupby(self, mask)
#    1880     def groupby(self, mask):
#    1881         """Create groupby instance"""
# -> 1882         return Groupby(self, mask)
#    1883
#    1884     def aggregate(self, mask, func):
#
# ~/.conda/envs/neuralsignature/lib/python3.8/site-packages/nltools/data/brain_data.py in __init__(self, data, mask)
#    2239
#    2240         data = check_brain_data(data)
# -> 2241         mask = check_brain_data(mask)
#    2242
#    2243         mask.data = np.round(mask.data).astype(int)
#
# ~/.conda/envs/neuralsignature/lib/python3.8/site-packages/nltools/utils.py in check_brain_data(data, mask)
# ...

# %%
behavdesign_bybeta,

# %%
subj_behav_design = wtpw1_behavdesign_clean[[s in train_subjs[0] for s in wtpw1_behavdesign_clean.subject]]

# %%
brain_data_mean =

# %%
def get_Brain_Data_betas_for_sub(
     v,
    behavdesign_bybeta,
    behavdesign_by,
    betaseries_path='/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/fx/models/WTP/wave1/betaseries/',
    mean_groups = 
):
    """
    Collect a bunch of beta files for specified subjects based on a behavioral design file
    and return them
    """
    subj_behav_design = behavdesign[[s in sub_label for s in behavdesign.subject]]
    del(behavdesign)
    
    if len(subj_behav_design)!=64:
        raise Exception("For "+sub_label+", expected 64 beta events but found " + str(len(subj_behav_design)))

    
    subject_dir = (
         betaseries_path + 'sub-' + sub_label + '/'
    )
        
    #set path for the betas

    #beta_path_sub049 = os.listdir(subject_dir)

    #iterate through the subjects
    # TO DO
    #iterate through and check all the betas exist
    for betafile in subj_behav_design.beta:
        betafilepath = subject_dir + betafile
        
        #check if file exists
        if os.path.exists(betafilepath):
            print('.',end='')
        else:
            print(betafilepath)
            raise Exception("beta " + betafile + ' does not exist')

    print("...verified that all expected betas exist! Processing...",flush=True,end='')



    #import them, but catch a very specific warning and don't show it because it gets annoying
    #https://docs.python.org/3/library/warnings.html
    with warnings.catch_warnings(record=True) as w:
        subj_data = nlt.Brain_Data([subject_dir + b for b in subj_behav_design.beta],
                                  X=subj_behav_design)
    na_inf_warn_count=0
    for wi in w:
        if wi.message.args[0]!='NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.':
            warnings.warn(wi.message,type(wi))
        else:
            na_inf_warn_count+=1

    if na_inf_warn_count>0:
        print("caught "+ str(na_inf_warn_count) + " instances of the warning:\n" + 
             'NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.')
        
    print('...imported data.')
    return(subj_data)

# %%
bd0

# %%
train_subjs.sort()

bd_dict={}
#get the brain data from the beta files
for sl in train_subjs:
    print(sl)
    bd = dev_wtp_io_utils.get_Brain_Data_betas_for_sub(
        sl, wtpw1_behavdesign_clean,betaseries_path = 
        '/gpfs/projects/sanlab/shared/DEV/nonbids_data/fMRI/fx/models/WTP/wave1/betaseries_ns/'
    )
    bd_dict[sl]=bd
